# %% [markdown]
# <a href="https://colab.research.google.com/github/sea-surface-teleconnections/sea-surface-teleconnections/blob/main/Reference_Cloud_Podaac_S3_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PODAAC CLOUD API S3 Datasets ⭐
#
# ---
# ---

# %% [markdown]
# >[PODAAC CLOUD API S3 Datasets ⭐](#scrollTo=x86uByJgZzzb)
#
# >>[Adding Subscriber Repo Python script](#scrollTo=JNoLuS7TahOZ)
#
# >[Listing Available datasets](#scrollTo=dkhet2UB8U_n)
#
# >>[Define function to determine environment](#scrollTo=2db7ad42)
#
# >[GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI](#scrollTo=UyDqAxFrfdGq)
#
# >>[Connecting to DataSets](#scrollTo=fA5dp8Xsc1KX)
#
# >>>[Code Block Repo Function 👽](#scrollTo=OGxeEOIJdfm3)
#
# >>>[Collecting Sets via S3 API from Main&Archived in Cloud ♎](#scrollTo=rseWFdrrd1Bn)
#
# >[Finding DataSet Based On Keywords ⚡](#scrollTo=EiJw4XGwkUhC)
#
# >[✌ Slicing and Indexing Variables:](#scrollTo=0MGJv6k7lAn_)
#
# >>[Finding Earliest Date Example](#scrollTo=gIW2IeYllftl)
#
# >[Subscribing to datasets](#scrollTo=m7aq0s38mgi1)
#
# >>[Attemping to download straight to Google colab](#scrollTo=2lmyKHihfhJ0)
#
# >[DataSubscriber UseCase](#scrollTo=yPfCFA4uMCHT)
#
# >[Direct Access to S3 Token](#scrollTo=uIXFrNnwjnMD)
#
# >[Authenticate](#scrollTo=RW9OApO7_opa)
#
# >[Creating Interactive Display Inline](#scrollTo=67dcQLr3i_v1)

# %%
# !pip install pyspark
# !pip install podaac-data-subscriber
# !pip install prettyprinter
# !pip install utils
# !pip install datetime 
import pandas as pd
import numpy as np
import pyspark.pandas as ps
from pyspark.sql import SparkSession

# %% [markdown]
# Using Pyspark, Podaac, Subscriber

# %%
# !git clone -l -s https://github.com/podaac/data-subscriber.git clonedgit

# %cd clonedgit
# !ls

# %%
# %cd subscriber/
# !ls
# Out:
# /content/clonedgit/subscriber
# __init__.py	  podaac_data_downloader.py
# podaac_access.py  podaac_data_subscriber.py

# %% [markdown]
# ## Adding Subscriber Repo Python script
#
#
#
# ---
#
#
#
# ---
#
#
#
# *   1.Exporting Script to Desktop
# *   2. Import Script back into Google Colab to save

# %%
import googleapiclient
#Save first then import 
from google.colab import files
#reading file cloned from github 
files.view('podaac_data_subscriber.py')
open_file = files.view('podaac_data_subscriber.py')

# %% [markdown]
# ---

# %%
# !git clone -l -s https://github.com/podaac/Data-Recipes.git datarecipes

# %%
# Accessing Existing collection in PODAAC CLOUD AWS S3
import utils
import pprint
import xarray as xr
from datetime import datetime
import warnings

warnings.simplefilter(action='ignore')

# %%
# !git clone https://github.com/podaac/Data-Recipes.git recipes
# %cd recipes
# !ls
# Out:
# Cloning into 'recipes'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 45 (delta 19), reused 27 (delta 10), pack-reused 0
# Unpacking objects: 100% (45/45), done.
# /content/clonedgit/subscriber/recipes
# dataset-introduction  LICENSE  README.md

# %%
# %cd dataset-introduction/
# Out:
# /content/clonedgit/subscriber/recipes/dataset-introduction

# %%
import googleapiclient
from google.colab import files
files.view('utils.py')
open_file = files.view('utils.py')

# %%
# Do not need to run 
files.upload()

# %%
# !pip install recipes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting recipes
#   Downloading recipes-0.1.tar.gz (926 bytes)
# Building wheels for collected packages: recipes
#   Building wheel for recipes (setup.py) ... done
#   Created wheel for recipes: filename=recipes-0.1-py3-none-any.whl size=1435 sha256=65ca371f29b751c81fd08b1a33c8c0a84ceebb50c4a529629a72b5f598749b38
#   Stored in directory: /root/.cache/pip/wheels/8b/10/2f/29a89c1d0a768aaed396e73eacd10ff356a8e6f25e4465ee2e
# Successfully built recipes
# Installing collected packages: recipes
# Successfully installed recipes-0.1

# %%
import requests
from pprint import pprint

CMR_OPS = 'https://cmr.earthdata.nasa.gov/search'
collection_url = 'https://cmr.earthdata.nasa.gov/search/collections'
var_url = "https://cmr.earthdata.nasa.gov/search/variables"

# %%
#urls = ['s3://' + f for f in fs.glob("s3://noaa-goes16/ABI-L2-SSTF/2020/210/*/*.nc")]

# %% [markdown]
# ---

# %% [markdown]
# # **Listing Available datasets**

# %% [markdown]
# ---
#
#
#
# ---

# %%
#@title Base Function to run
"""
Some ground level functions
"""

import requests
from pprint import pprint
CMR_OPS = 'https://cmr.earthdata.nasa.gov/search'
collection_url = 'https://cmr.earthdata.nasa.gov/search/collections'
var_url = "https://cmr.earthdata.nasa.gov/search/variables"

def find_dataset(provider='podaac',
                 keywords=['swot','level-2']):
    """
    Find a list of collections/datasets that match all the keywords from the keywords list.
    
    
    """
    import pandas as pd

    if 'podaac' in provider.lower().replace('.',''):
        provider='POCLOUD'
        
    response = requests.get(collection_url,params={'cloud_hosted': 'True',
                                        'has_granules': 'True',
                                        'provider': provider,
                                        'page_size':2000,},
                                headers={'Accept': 'application/json', } )
    
    collections = response.json()['feed']['entry']
    
    entries={}
    entries['short_name']=[]
    entries['long_name']=[]
    entries['concept_id']=[]
    entries['time_start']=[]
    entries['time_end']=[]
    
    
    for collection in collections:
        
        title="%s %s %s"%(collection["short_name"],collection["dataset_id"][:97],collection["id"])
        match=1
        for kw in keywords:
            match *= kw.lower() in title.lower()
            
        if match==1:
            entries['short_name'].append(collection["short_name"])
            entries['concept_id'].append(collection["id"])
            entries['long_name'].append(collection["dataset_id"])
            entries['time_start'].append(collection["time_start"])
            try:
                entries['time_end'].append(collection["time_end"])
            except:
                entries['time_end'].append(['NaT/Present'])
    
    return pd.DataFrame(entries)

def all_pocloud_dataset(provider='podaac'):
    """
    a list of all POCLOUD collections.
    """
    import pandas as pd

    if 'podaac' in provider.lower().replace('.',''):
        provider='POCLOUD'
        
    response = requests.get(collection_url,params={'cloud_hosted': 'True',
                                        'provider': provider,
                                        'page_size':2000,},
                                headers={'Accept': 'application/json', } )
    
    collections = response.json()['feed']['entry']
    
    entries={}
    entries['short_name']=[]
    entries['long_name']=[]
    entries['concept_id']=[]
    entries['time_start']=[]
    entries['time_end']=[]
    
    
    for collection in collections:
        
        title="%s %s %s"%(collection["short_name"],collection["dataset_id"][:97],collection["id"])
        match=1
        entries['short_name'].append(collection["short_name"])
        entries['concept_id'].append(collection["id"])
        entries['long_name'].append(collection["dataset_id"])
        entries['time_start'].append(collection["time_start"][:10])
        try:
            entries['time_end'].append(collection["time_end"][:10])
        except:
            entries['time_end'].append(['NaT/Present'])
    
    return pd.DataFrame(entries)

def direct_s3(provider='podaac'):
    import requests,s3fs
    s3_cred_endpoint = {
        'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials',
        'lpdaac':'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'}

    temp_creds_url = s3_cred_endpoint[provider]
    creds = requests.get(temp_creds_url).json()
    s3 = s3fs.S3FileSystem(anon=False,
                           key=creds['accessKeyId'],
                           secret=creds['secretAccessKey'], 
                           token=creds['sessionToken'])
    return s3

# %%
import utils
import warnings
import pandas as pd
import time
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', 150)
warnings.simplefilter(action='ignore')

data = all_pocloud_dataset('https://archive.podaac.earthdata.nasa.gov/s3credentials')
display(data)
# Out:
#                                                       short_name  \
# 0                                        MODIS_A-JPL-L2P-v2019.0
# 1                                        MODIS_T-JPL-L2P-v2019.0
# 2                                                 ASCATB-L2-25km
# 3                                                 ASCATC-L2-25km
# 4                                       VIIRS_NPP-STAR-L3U-v2.80
# 5                                           MUR-JPL-L4-GLOB-v4.1
# 6                                       VIIRS_N20-OSPO-L2P-v2.61
# 7                                       VIIRS_NPP-OSPO-L2P-v2.61
# 8                           JASON_CS_S6A_L2_ALT_HR_STD_OST_NRT_F
# 9                                       VIIRS_N20-STAR-L3U-v2.80
# 10                                             ASCATB-L2-Coastal
# 11                                             ASCATC-L2-Coastal
# 12                                                CYGNSS_L1_V3.1
# 13                                      VIIRS_N20-OSPO-L3U-v2.61
# 14                          JASON_CS_S6A_L2_ALT_LR_STD_OST_NRT_F
# 15                                       VIIRS_NPP-NAVO-L2P-v3.0
# 16                                      VIIRS_NPP-OSPO-L3U-v2.61
# 17                                      VIIRS_N20-STAR-L2P-v2.80
# 18                                                CYGNSS_L1_V3.0
# 19                                        OSCAR_L4_OC_FINAL_V2.0
# 20                                      VIIRS_NPP-STAR-L2P-v2.80
# 21                                      AVHRRF_MB-STAR-L3U-v2.80
# 22                             AVHRR_SST_METOP_B-OSISAF-L2P-v1.0
# 23                        ECCO_L4_TEMP_SALINITY_05DEG_DAILY_V4R4
# 24                          JASON_CS_S6A_L2_ALT_LR_STD_OST_STC_F
# 25                                 SEVIRI_IO_SST-OSISAF-L3C-v1.0
# 26                                    SEVIRI_SST-OSISAF-L3C-v1.0
# 27                                        ABI_G16-STAR-L3C-v2.70
# 28                                       MUR25-JPL-L4-GLOB-v04.2
# 29                                        ABI_G16-STAR-L2P-v2.70
# 30                          JASON_CS_S6A_L2_ALT_HR_STD_OST_STC_F
# 31                          JASON_CS_S6A_L2_ALT_LR_RED_OST_NRT_F
# 32                                       OSTIA-UKMO-L4-GLOB-v2.0
# 33                                   SMAP_JPL_L2B_NRT_SSS_CAP_V5
# 34                                        ABI_G17-STAR-L3C-v2.71
# 35                                      AVHRRF_MC-STAR-L3U-v2.80
# 36                                    CMC0.1deg-CMC-L4-GLOB-v3.0
# 37                                                CYGNSS_L2_V3.1
# 38                            ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4
# 39                                  ECCO_L4_SSH_05DEG_DAILY_V4R4
# 40                      ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4
# 41                                 JASON_CS_S6A_L1B_ALT_HR_NTC_F
# 42              JASON_CS_S6A_L2_ALT_HR_STD_OST_NTC_F_UNVALIDATED
# 43              JASON_CS_S6A_L2_ALT_LR_STD_OST_NTC_F_UNVALIDATED
# 44                                      K10_SST-NAVO-L4-GLOB-v01
# 45   SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL1812
# 46                      TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
# 47                                           AMSR2-REMSS-L2P-v8a
# 48                                        AMSR2-REMSS-L2P_RT_v8a
# 49                                                ASCATA-L2-25km
# 50                                      AVHRRMTA_G-NAVO-L2P-v1.0
# 51                                      AVHRRMTB_G-NAVO-L2P-v1.0
# 52                                    AVHRR_OI-NCEI-L4-GLOB-v2.1
# 53                                            CYGNSS_L2_CDR_V1.1
# 54                               CYGNSS_L2_SURFACE_FLUX_CDR_V1.0
# 55                               CYGNSS_L2_SURFACE_FLUX_CDR_V1.1
# 56                                                CYGNSS_L2_V3.0
# 57                                 CYGNSS_NOAA_L2_SWSP_25KM_V1.1
# 58                                 CYGNSS_NOAA_L2_SWSP_25KM_V1.2
# 59                     ECCO_L4_DENS_STRAT_PRESS_05DEG_DAILY_V4R4
# 60                            ECCO_L4_OCEAN_VEL_05DEG_DAILY_V4R4
# 61               ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_DAILY_V4R4
# 62                                ECCO_L4_SSH_05DEG_MONTHLY_V4R4
# 63                                  GAMSSA_28km-ABOM-L4-GLOB-v01
# 64                               GRACEFO_L1B_ASCII_GRAV_JPL_RL04
# 65                                       JASON_3_L2_OST_OGDR_GPS
# 66                                 JASON_CS_S6A_L1A_ALT_HR_NTC_F
# 67                          JASON_CS_S6A_L2_ALT_HR_RED_OST_NRT_F
# 68                          JASON_CS_S6A_L2_ALT_HR_RED_OST_STC_F
# 69              JASON_CS_S6A_L2_ALT_LR_RED_OST_NTC_F_UNVALIDATED
# 70                          JASON_CS_S6A_L2_ALT_LR_RED_OST_STC_F
# 71                                   JASON_CS_S6A_L2_AMR_RAD_NRT
# 72                                   JASON_CS_S6A_L2_AMR_RAD_STC
# 73                  MITgcm_LLC4320_Pre-SWOT_JPL_L4_ACC_SMST_v1.0
# 74           MODIS_AQUA_L3_SST_THERMAL_DAILY_4KM_DAYTIME_V2019.0
# 75          MODIS_TERRA_L3_SST_THERMAL_DAILY_4KM_DAYTIME_V2019.0
# 76                                           MSG03-OSPO-L2P-v1.0
# 77                                 OISSS_L4_multimission_7day_v1
# 78                                          OSCAR_L4_OC_NRT_V2.0
# 79                                       SMAP_JPL_L2B_SSS_CAP_V5
# 80                       SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5
# 81                                            SMAP_RSS_L2_SSS_V4
# 82            SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1
# 83           SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_SCIENCE_V1
# 84                  SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_CALVAL_V1
# 85            SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_CALVAL_V1
# 86           SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_SCIENCE_V1
# 87                  SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_CALVAL_V1
# 88                 SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_SCIENCE_V1
# 89                     TELLUS_GLDAS-NOAH-3.3_TWS-ANOMALY_MONTHLY
# 90                                              TMI-REMSS-L2P-v4
# 91                                     VIIRS_NPP-JPL-L2P-v2016.2
# 92                                       VIIRS_NPP-NAVO-L2P-v1.0
# 93                                        ABI_G17-STAR-L2P-v2.71
# 94                                        AHI_H08-STAR-L2P-v2.70
# 95                                        AHI_H08-STAR-L3C-v2.70
# 96                                     ALTIKA_SARAL_L2_OST_XOGDR
# 97                 ALT_TIDE_GAUGE_L4_OST_SLA_US_WEST_COAST_DAILY
# 98                                           AMSR2-REMSS-L3U-v8a
# 99                                        AMSR2-REMSS-L3U_RT-v8a
# 100        ANTARCTICA_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 101                                           AQUARIUS_L2_SSS_V5
# 102                      AQUARIUS_L3_SSS_SMI_7DAY-RUNNINGMEAN_V5
# 103                                            ASCATA-L2-Coastal
# 104                                        ASCATA_L2_COASTAL_CDR
# 105                                      AVHRR19_G-NAVO-L2P-v1.0
# 106                                      AVHRR19_L-NAVO-L2P-v1.0
# 107                                     AVHRRF_MA-STAR-L2P-v2.80
# 108                                     AVHRRF_MA-STAR-L3U-v2.80
# 109                                     AVHRRF_MB-STAR-L2P-v2.80
# 110                                     AVHRRF_MC-STAR-L2P-v2.80
# 111                                     AVHRRMTA_G-NAVO-L2P-v2.0
# 112                                     AVHRRMTB_G-NAVO-L2P-v2.0
# 113                                     AVHRRMTC_G-NAVO-L2P-v2.0
# 114                        AVHRR_SST_METOP_B_GLB-OSISAF-L3C-v1.0
# 115                        AVHRR_SST_METOP_B_NAR-OSISAF-L3C-v1.0
# 116                                           CYGNSS_L1_CDR_V1.0
# 117                                           CYGNSS_L1_CDR_V1.1
# 118                                           CYGNSS_L1_FULL_DDM
# 119                                      CYGNSS_L1_FULL_DDM_V3.0
# 120                                             CYGNSS_L1_RAW_IF
# 121                                               CYGNSS_L1_V2.1
# 122                                           CYGNSS_L2_CDR_V1.0
# 123                                  CYGNSS_L2_SURFACE_FLUX_V1.0
# 124                                               CYGNSS_L2_V2.1
# 125                                           CYGNSS_L3_CDR_V1.0
# 126                                           CYGNSS_L3_CDR_V1.1
# 127                                  CYGNSS_L3_MICROPLASTIC_V1.0
# 128                                               CYGNSS_L3_S1.0
# 129                                 CYGNSS_L3_SOIL_MOISTURE_V1.0
# 130                                               CYGNSS_L3_V2.1
# 131                                               CYGNSS_L3_V3.0
# 132                                               CYGNSS_L3_V3.1
# 133                                      DMI_OI-DMI-L4-GLOB-v1.0
# 134                                  ECCO_L4_ANCILLARY_DATA_V4R4
# 135                         ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4
# 136                     ECCO_L4_ATM_STATE_LLC0090GRID_DAILY_V4R4
# 137                   ECCO_L4_ATM_STATE_LLC0090GRID_MONTHLY_V4R4
# 138                               ECCO_L4_BOLUS_05DEG_DAILY_V4R4
# 139                             ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4
# 140                         ECCO_L4_BOLUS_LLC0090GRID_DAILY_V4R4
# 141                       ECCO_L4_BOLUS_LLC0090GRID_MONTHLY_V4R4
# 142                  ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4
# 143              ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_DAILY_V4R4
# 144            ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_MONTHLY_V4R4
# 145                          ECCO_L4_FRESH_FLUX_05DEG_DAILY_V4R4
# 146                        ECCO_L4_FRESH_FLUX_05DEG_MONTHLY_V4R4
# 147                    ECCO_L4_FRESH_FLUX_LLC0090GRID_DAILY_V4R4
# 148                  ECCO_L4_FRESH_FLUX_LLC0090GRID_MONTHLY_V4R4
# 149                                  ECCO_L4_GEOMETRY_05DEG_V4R4
# 150                            ECCO_L4_GEOMETRY_LLC0090GRID_V4R4
# 151                       ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4
# 152                      ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4B
# 153                          ECCO_L4_GMSL_TIME_SERIES_DAILY_V4R4
# 154                        ECCO_L4_GMSL_TIME_SERIES_MONTHLY_V4R4
# 155                           ECCO_L4_HEAT_FLUX_05DEG_DAILY_V4R4
# 156                         ECCO_L4_HEAT_FLUX_05DEG_MONTHLY_V4R4
# 157                     ECCO_L4_HEAT_FLUX_LLC0090GRID_DAILY_V4R4
# 158                   ECCO_L4_HEAT_FLUX_LLC0090GRID_MONTHLY_V4R4
# 159                   ECCO_L4_MIXED_LAYER_DEPTH_05DEG_DAILY_V4R4
# 160                 ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4
# 161             ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_DAILY_V4R4
# 162           ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_MONTHLY_V4R4
# 163                                 ECCO_L4_OBP_05DEG_DAILY_V4R4
# 164                                ECCO_L4_OBP_05DEG_DAILY_V4R4B
# 165                               ECCO_L4_OBP_05DEG_MONTHLY_V4R4
# 166                              ECCO_L4_OBP_05DEG_MONTHLY_V4R4B
# 167                           ECCO_L4_OBP_LLC0090GRID_DAILY_V4R4
# 168                          ECCO_L4_OBP_LLC0090GRID_DAILY_V4R4B
# 169                         ECCO_L4_OBP_LLC0090GRID_MONTHLY_V4R4
# 170                        ECCO_L4_OBP_LLC0090GRID_MONTHLY_V4R4B
# 171                        ECCO_L4_OBP_LLC0090GRID_SNAPSHOT_V4R4
# 172                       ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4
# 173                 ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4
# 174        ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_DAILY_V4R4
# 175      ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_MONTHLY_V4R4
# 176        ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_DAILY_V4R4
# 177      ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_MONTHLY_V4R4
# 178     ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_DAILY_V4R4
# 179   ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_MONTHLY_V4R4
# 180          ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 181        ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 182    ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_DAILY_V4R4
# 183  ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_MONTHLY_V4R4
# 184                         ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4
# 185                     ECCO_L4_OCEAN_VEL_LLC0090GRID_DAILY_V4R4
# 186                   ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4
# 187                   ECCO_L4_SBO_CORE_TIME_SERIES_SNAPSHOT_V4R4
# 188                  ECCO_L4_SBO_CORE_TIME_SERIES_SNAPSHOT_V4R4B
# 189            ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_MONTHLY_V4R4
# 190        ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_DAILY_V4R4
# 191      ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_MONTHLY_V4R4
# 192     ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_SNAPSHOT_V4R4
# 193     ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 194   ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 195       ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 196     ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 197                    ECCO_L4_SEA_ICE_VELOCITY_05DEG_DAILY_V4R4
# 198                  ECCO_L4_SEA_ICE_VELOCITY_05DEG_MONTHLY_V4R4
# 199              ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_DAILY_V4R4
# 200            ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_MONTHLY_V4R4
# 201           ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_SNAPSHOT_V4R4
# 202                                ECCO_L4_SSH_05DEG_DAILY_V4R4B
# 203                              ECCO_L4_SSH_05DEG_MONTHLY_V4R4B
# 204                           ECCO_L4_SSH_LLC0090GRID_DAILY_V4R4
# 205                          ECCO_L4_SSH_LLC0090GRID_DAILY_V4R4B
# 206                         ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4
# 207                        ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4B
# 208                        ECCO_L4_SSH_LLC0090GRID_SNAPSHOT_V4R4
# 209                              ECCO_L4_STRESS_05DEG_DAILY_V4R4
# 210                            ECCO_L4_STRESS_05DEG_MONTHLY_V4R4
# 211                        ECCO_L4_STRESS_LLC0090GRID_DAILY_V4R4
# 212                      ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4
# 213                 ECCO_L4_TEMP_SALINITY_LLC0090GRID_DAILY_V4R4
# 214               ECCO_L4_TEMP_SALINITY_LLC0090GRID_MONTHLY_V4R4
# 215              ECCO_L4_TEMP_SALINITY_LLC0090GRID_SNAPSHOT_V4R4
# 216                                           EWSG1-NAVO-L2P-v01
# 217                                          GMI-REMSS-L3U-v8.2a
# 218                                         GOES15-OSPO-L2P-v1.0
# 219                                   GOES16-SST-OSISAF-L3C-v1.0
# 220                              GRACEFO_L1A_ASCII_GRAV_JPL_RL04
# 221                                  GRACEFO_L2_CSR_MONTHLY_0060
# 222                                  GRACEFO_L2_GFZ_MONTHLY_0060
# 223                                  GRACEFO_L2_JPL_MONTHLY_0060
# 224                                    GRACE_AOD1B_GRAV_GFZ_RL06
# 225                         GRC-GFO_GRIDDED_AOD1B_JPL_1-DEG_RL06
# 226                        GRC-GFO_GRIDDED_AOD1B_JPL_MASCON_RL06
# 227         GREENLAND_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 228                          Geo_Polar_Blended-OSPO-L4-GLOB-v1.0
# 229                    Geo_Polar_Blended_Night-OSPO-L4-GLOB-v1.0
# 230                             IASI_SST_METOP_B-OSISAF-L2P-v1.0
# 231                                JASON_CS_S6A_L1A_ALT_HR_STC_F
# 232                                JASON_CS_S6A_L1B_ALT_HR_STC_F
# 233                                JASON_CS_S6A_L1B_ALT_LR_NTC_F
# 234                                JASON_CS_S6A_L1B_ALT_LR_STC_F
# 235                          JASON_CS_S6A_L1B_GNSS_RO_POD_HOURLY
# 236                         JASON_CS_S6A_L2_ALT_HR_RED_OST_NTC_F
# 237             JASON_CS_S6A_L2_ALT_HR_RED_OST_NTC_F_UNVALIDATED
# 238                         JASON_CS_S6A_L2_ALT_HR_STD_OST_NTC_F
# 239                         JASON_CS_S6A_L2_ALT_LR_RED_OST_NTC_F
# 240                         JASON_CS_S6A_L2_ALT_LR_STD_OST_NTC_F
# 241                                  JASON_CS_S6A_L2_AMR_RAD_NTC
# 242                      JASON_CS_S6A_L2_AMR_RAD_NTC_UNVALIDATED
# 243                                        L3S_LEO_AM-STAR-v2.80
# 244                                        L3S_LEO_PM-STAR-v2.80
# 245                                MERGED_TP_J1_OSTM_OST_ALL_V51
# 246                             MERGED_TP_J1_OSTM_OST_CYCLES_V51
# 247                         MERGED_TP_J1_OSTM_OST_GMSL_ASCII_V51
# 248               MITgcm_LLC4320_Pre-SWOT_JPL_L4_BassStrait_v1.0
# 249                   MITgcm_LLC4320_Pre-SWOT_JPL_L4_Boknis_v1.0
# 250                MITgcm_LLC4320_Pre-SWOT_JPL_L4_CapeBasin_v1.0
# 251             MITgcm_LLC4320_Pre-SWOT_JPL_L4_GotlandBasin_v1.0
# 252              MITgcm_LLC4320_Pre-SWOT_JPL_L4_LabradorSea_v1.0
# 253               MITgcm_LLC4320_Pre-SWOT_JPL_L4_MarmaraSea_v1.0
# 254              MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWAustralia_v1.0
# 255                MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWPacific_v1.0
# 256             MITgcm_LLC4320_Pre-SWOT_JPL_L4_NewCaledonia_v1.0
# 257                 MITgcm_LLC4320_Pre-SWOT_JPL_L4_ROAM_MIZ_v1.0
# 258            MITgcm_LLC4320_Pre-SWOT_JPL_L4_RockallTrough_v1.0
# 259             MITgcm_LLC4320_Pre-SWOT_JPL_L4_WestAtlantic_v1.0
# 260               MITgcm_LLC4320_Pre-SWOT_JPL_L4_WesternMed_v1.0
# 261                  MITgcm_LLC4320_Pre-SWOT_JPL_L4_Yongala_v1.0
# 262          MODIS_AQUA_L3_SST_MID-IR_8DAY_4KM_NIGHTTIME_V2019.0
# 263          MODIS_AQUA_L3_SST_MID-IR_8DAY_9KM_NIGHTTIME_V2019.0
# 264        MODIS_AQUA_L3_SST_MID-IR_ANNUAL_4KM_NIGHTTIME_V2019.0
# 265        MODIS_AQUA_L3_SST_MID-IR_ANNUAL_9KM_NIGHTTIME_V2019.0
# 266         MODIS_AQUA_L3_SST_MID-IR_DAILY_4KM_NIGHTTIME_V2019.0
# 267         MODIS_AQUA_L3_SST_MID-IR_DAILY_9KM_NIGHTTIME_V2019.0
# 268       MODIS_AQUA_L3_SST_MID-IR_MONTHLY_4KM_NIGHTTIME_V2019.0
# 269       MODIS_AQUA_L3_SST_MID-IR_MONTHLY_9KM_NIGHTTIME_V2019.0
# 270           MODIS_AQUA_L3_SST_THERMAL_8DAY_4KM_DAYTIME_V2019.0
# 271         MODIS_AQUA_L3_SST_THERMAL_8DAY_4KM_NIGHTTIME_V2019.0
# 272           MODIS_AQUA_L3_SST_THERMAL_8DAY_9KM_DAYTIME_V2019.0
# 273         MODIS_AQUA_L3_SST_THERMAL_8DAY_9KM_NIGHTTIME_V2019.0
# 274         MODIS_AQUA_L3_SST_THERMAL_ANNUAL_4KM_DAYTIME_V2019.0
# 275       MODIS_AQUA_L3_SST_THERMAL_ANNUAL_4KM_NIGHTTIME_V2019.0
# 276         MODIS_AQUA_L3_SST_THERMAL_ANNUAL_9KM_DAYTIME_V2019.0
# 277       MODIS_AQUA_L3_SST_THERMAL_ANNUAL_9KM_NIGHTTIME_V2019.0
# 278        MODIS_AQUA_L3_SST_THERMAL_DAILY_4KM_NIGHTTIME_V2019.0
# 279          MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# 280        MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_NIGHTTIME_V2019.0
# 281        MODIS_AQUA_L3_SST_THERMAL_MONTHLY_4KM_DAYTIME_V2019.0
# 282      MODIS_AQUA_L3_SST_THERMAL_MONTHLY_4KM_NIGHTTIME_V2019.0
# 283        MODIS_AQUA_L3_SST_THERMAL_MONTHLY_9KM_DAYTIME_V2019.0
# 284      MODIS_AQUA_L3_SST_THERMAL_MONTHLY_9KM_NIGHTTIME_V2019.0
# 285         MODIS_TERRA_L3_SST_MID-IR_8DAY_4KM_NIGHTTIME_V2019.0
# 286         MODIS_TERRA_L3_SST_MID-IR_8DAY_9KM_NIGHTTIME_V2019.0
# 287       MODIS_TERRA_L3_SST_MID-IR_ANNUAL_4KM_NIGHTTIME_V2019.0
# 288       MODIS_TERRA_L3_SST_MID-IR_ANNUAL_9KM_NIGHTTIME_V2019.0
# 289        MODIS_TERRA_L3_SST_MID-IR_DAILY_4KM_NIGHTTIME_V2019.0
# 290        MODIS_TERRA_L3_SST_MID-IR_DAILY_9KM_NIGHTTIME_V2019.0
# 291      MODIS_TERRA_L3_SST_MID-IR_MONTHLY_4KM_NIGHTTIME_V2019.0
# 292      MODIS_TERRA_L3_SST_MID-IR_MONTHLY_9KM_NIGHTTIME_V2019.0
# 293          MODIS_TERRA_L3_SST_THERMAL_8DAY_4KM_DAYTIME_V2019.0
# 294        MODIS_TERRA_L3_SST_THERMAL_8DAY_4KM_NIGHTTIME_V2019.0
# 295          MODIS_TERRA_L3_SST_THERMAL_8DAY_9KM_DAYTIME_V2019.0
# 296        MODIS_TERRA_L3_SST_THERMAL_8DAY_9KM_NIGHTTIME_V2019.0
# 297        MODIS_TERRA_L3_SST_THERMAL_ANNUAL_4KM_DAYTIME_V2019.0
# 298      MODIS_TERRA_L3_SST_THERMAL_ANNUAL_4KM_NIGHTTIME_V2019.0
# 299        MODIS_TERRA_L3_SST_THERMAL_ANNUAL_9KM_DAYTIME_V2019.0
# 300      MODIS_TERRA_L3_SST_THERMAL_ANNUAL_9KM_NIGHTTIME_V2019.0
# 301       MODIS_TERRA_L3_SST_THERMAL_DAILY_4KM_NIGHTTIME_V2019.0
# 302         MODIS_TERRA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# 303       MODIS_TERRA_L3_SST_THERMAL_DAILY_9KM_NIGHTTIME_V2019.0
# 304       MODIS_TERRA_L3_SST_THERMAL_MONTHLY_4KM_DAYTIME_V2019.0
# 305     MODIS_TERRA_L3_SST_THERMAL_MONTHLY_4KM_NIGHTTIME_V2019.0
# 306       MODIS_TERRA_L3_SST_THERMAL_MONTHLY_9KM_DAYTIME_V2019.0
# 307     MODIS_TERRA_L3_SST_THERMAL_MONTHLY_9KM_NIGHTTIME_V2019.0
# 308                                  MW_IR_OI-REMSS-L4-GLOB-v5.0
# 309                                     MW_OI-REMSS-L4-GLOB-v5.0
# 310             OCEAN_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 311                             OISSS_L4_multimission_monthly_v1
# 312                                 OISST_HR_NRT-GOS-L4-BLK-v2.0
# 313                                 OISST_HR_NRT-GOS-L4-MED-v2.0
# 314                                OISST_UHR_NRT-GOS-L4-BLK-v2.0
# 315                                OISST_UHR_NRT-GOS-L4-MED-v2.0
# 316                            OS2_OSCAT_LEVEL_2B_OWV_COMP_12_V2
# 317                                     OSCAR_L4_OC_INTERIM_V2.0
# 318     PRESWOT_HYDRO_GRRATS_L2_DAILY_VIRTUAL_STATION_HEIGHTS_V2
# 319           PRESWOT_HYDRO_GRRATS_L2_VIRTUAL_STATION_HEIGHTS_V2
# 320                       PRESWOT_HYDRO_L2_GREALM_LAKE_HEIGHT_V2
# 321                       PRESWOT_HYDRO_L3_LAKE_RESEVOIR_AREA_V2
# 322                 PRESWOT_HYDRO_L4_LAKE_STORAGE_TIME_SERIES_V2
# 323                   QSCAT_LEVEL_2B_OWV_COMP_12_KUSST_LCRES_4.1
# 324                           QSCAT_LEVEL_2B_OWV_COMP_12_LCR_3.1
# 325                                  RAMSSA_09km-ABOM-L4-AUS-v01
# 326                                  REYNOLDS_NCDC_L4_MONTHLY_V5
# 327                                RSCAT_LEVEL_2B_OWV_CLIM_12_V2
# 328                                          SEAGLIDER_GUAM_2019
# 329                                SEVIRI_SST_DR-OSISAF-L3C-v1.0
# 330                               SMAP_JPL_L3_SSS_CAP_MONTHLY_V5
# 331                      SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4
# 332                               SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
# 333                                     SWOT_PRELAUNCH_L2_BPR_V1
# 334                                  SWOT_PRELAUNCH_L2_GLIDER_V1
# 335                                     SWOT_PRELAUNCH_L2_GPS_V1
# 336                                    SWOT_PRELAUNCH_L2_PIES_V1
# 337                                 SWOT_PRELAUNCH_L2_PRAWLER_V1
# 338                                  SWOT_PRELAUNCH_L2_SIOCTD_V1
# 339                                 SWOT_PRELAUNCH_L2_WHOICTD_V1
# 340                                      SWOT_PRELAUNCH_L2_WW_V1
# 341                SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_SCIENCE_V1
# 342                  SWOT_SIMULATED_NA_CONTINENT_L2_HR_LAKESP_V1
# 343                 SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXCVEC_V1
# 344                    SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXC_V1
# 345                  SWOT_SIMULATED_NA_CONTINENT_L2_HR_RASTER_V1
# 346                 SWOT_SIMULATED_NA_CONTINENT_L2_HR_RIVERSP_V1
# 347                         TELLUS_GRAC-GRFO_MASCON_GRID_RL06_V2
# 348                                      VIIRS_NPP-NAVO-L2P-v2.0
# 349                            VIIRS_SST_NPP_NAR-OSISAF-L3C-v1.0
# 350                                    WindSat-REMSS-L3U-v7.0.1a
#
#                                                                                                                                                  long_name  \
# 0     GHRSST Level 2P Global Sea Surface Skin Temperature from the Moderate Resolution Imaging Spectroradiometer (MODIS) on the NASA Aqua satellite (GDS2)
# 1    GHRSST Level 2P Global Sea Surface Skin Temperature from the Moderate Resolution Imaging Spectroradiometer (MODIS) on the NASA Terra satellite (GDS2)
# 2                                                                              MetOp-B ASCAT Level 2 25.0km Ocean Surface Wind Vectors in Full Orbit Swath
# 3                                                                              MetOp-C ASCAT Level 2 25.0km Ocean Surface Wind Vectors in Full Orbit Swath
# 4                                                                                        GHRSST Level 3U NOAA STAR SST v2.80 from VIIRS on S-NPP Satellite
# 5                                                                             GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 6                                                                          GHRSST Level 2P OSPO dataset v2.61 from VIIRS on the NOAA-20 satellite (GDS v2)
# 7                                                                                GHRSST Level 2P OSPO dataset v2.61 from VIIRS on S-NPP Satellite (GDS v2)
# 8                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NRT Ocean Surface Topography
# 9                                                                                      GHRSST Level 3U NOAA STAR SST v2.80 from VIIRS on NOAA-20 Satellite
# 10                                                                            MetOp-B ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 11                                                                            MetOp-C ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 12                                                                                                          CYGNSS Level 1 Science Data Record Version 3.1
# 13                                                                             GHRSST Level 3U OSPO dataset v2.61 from VIIRS on NOAA-20 Satellite (GDS v2)
# 14                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NRT Ocean Surface Topography
# 15   GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 16                                                                               GHRSST Level 3U OSPO dataset v2.61 from VIIRS on S-NPP Satellite (GDS v2)
# 17                                                                                    GHRSST Level 2P NOAA STAR SST  v2.80 from VIIRS on NOAA-20 Satellite
# 18                                                                                                          CYGNSS Level 1 Science Data Record Version 3.0
# 19                                                     Ocean Surface Current Analyses Real-time (OSCAR) Surface Currents - Final 0.25 Degree (Version 2.0)
# 20                                                                                       GHRSST Level 2P NOAA STAR SST v2.80 from VIIRS on S-NPP Satellite
# 21                                                                               GHRSST NOAA/STAR Metop-B AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 22   GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 23                                                                       ECCO Ocean Temperature and Salinity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 24                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) STC Ocean Surface Topography
# 25   GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 26   GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
# 27                                                                              GHRSST NOAA/STAR GOES-16 ABI  L3C America Region SST v2.70 dataset in GDS2
# 28                                                                    GHRSST Level 4 MUR 0.25deg Global Foundation Sea Surface Temperature Analysis (v4.2)
# 29                                                                               GHRSST NOAA/STAR GOES-16 ABI L2P America Region SST v2.70 dataset in GDS2
# 30                                                               Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) STC Ocean Surface Topography
# 31                                                        Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NRT Reduced Ocean Surface Topography
# 32                                                                 GHRSST Level 4 OSTIA Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 33                                                                        JPL SMAP Level 2B Near Real-time CAP Sea Surface Salinity V5.0 Validated Dataset
# 34                                                                              GHRSST NOAA/STAR GOES-17 ABI  L3C America Region SST v2.71 dataset in GDS2
# 35                                                                               GHRSST NOAA/STAR Metop-C AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 36                                                             GHRSST Level 4 CMC0.1deg Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 37                                                                                                          CYGNSS Level 2 Science Data Record Version 3.1
# 38                                         ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# 39                                                                                   ECCO Sea Surface Height - Daily Mean 0.5 Degree (Version 4 Release 4)
# 40                                                                     ECCO Ocean Temperature and Salinity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 41                                                                  Sentinel-6A MF Jason-CS L1B P4 Altimeter High Resolution (HR) NTC Geolocated Waveforms
# 42                                                 Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NTC Ocean Surface Topography (Unvalidated)
# 43                                                  Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NTC Ocean Surface Topography (Unvalidated)
# 44                                   GHRSST Level 4 K10_SST Global 10 km Analyzed Sea Surface Temperature from Naval Oceanographic Office (NAVO) in GDS2.0
# 45                                                                                              MEaSUREs Gridded Sea Surface Height Anomalies Version 1812
# 46     JPL GRACE and GRACE-FO Mascon Ocean, Ice, and Hydrology Equivalent Water Height Coastal Resolution Improvement (CRI) Filtered Release 06 Version 02
# 47             GHRSST Level 2P Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 48   GHRSST Level 2P Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 49                                                                                                MetOp-A ASCAT Level 2 25.0 km Ocean Surface Wind Vectors
# 50   GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-A satellite produced by NAVO
# 51   GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-B satellite produced by NAVO
# 52                                                                GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# 53                                                                                                          CYGNSS Level 2 Climate Data Record Version 1.1
# 54                                                                                  CYGNSS Level 2 Ocean Surface Heat Flux Climate Data Record Version 1.0
# 55                                                                                  CYGNSS Level 2 Ocean Surface Heat Flux Climate Data Record Version 1.1
# 56                                                                                                          CYGNSS Level 2 Science Data Record Version 3.0
# 57                                                                                        NOAA CYGNSS Level 2 Science Wind Speed 25-km Product Version 1.1
# 58                                                                                        NOAA CYGNSS Level 2 Science Wind Speed 25-km Product Version 1.2
# 59                                              ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# 60                                                                                       ECCO Ocean Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 61                                                         ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean 0.5 Degree (Version 4 Release 4)
# 62                                                                                 ECCO Sea Surface Height - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 63                                                       GHRSST Level 4 GAMSSA_28km Global Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 64                                                                                                 GRACE-FO Level-1B Release version 4.0 from JPL in ASCII
# 65                                                                                                                   Jason-3 GPS based orbit and SSHA OGDR
# 66                                     Sentinel-6A MF Jason-CS L1A P4 Altimeter High Resolution (HR) NTC Intermediate Outputs with Instrument Calibrations
# 67                                                       Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NRT Reduced Ocean Surface Topography
# 68                                                       Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) STC Reduced Ocean Surface Topography
# 69                                          Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NTC Reduced Ocean Surface Topography (Unvalidated)
# 70                                                        Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) STC Reduced Ocean Surface Topography
# 71                                                             Sentinel-6A MF Jason-CS L2 Advanced Microwave Radiometer (AMR-C) NRT Geophysical Parameters
# 72                                                             Sentinel-6A MF Jason-CS L2 Advanced Microwave Radiometer (AMR-C) STC Geophysical Parameters
# 73                                                 Southern Ocean Pre-SWOT Level-4 Hourly MITgcm LLC4320 Native Grid 2km Oceanographic Dataset Version 1.0
# 74                                                                                            MODIS Aqua Level 3 SST Thermal IR  Daily 4km Daytime V2019.0
# 75                                                                                            MODIS Terra Level 3 SST Thermal IR Daily 4km Daytime V2019.0
# 76   GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Sec...
# 77                                                                             Multi-Mission Optimally Interpolated Sea Surface Salinity Global Dataset V1
# 78                                            Ocean Surface Current Analyses Real-time (OSCAR) Surface Currents - Near Real Time 0.25 Degree (Version 2.0)
# 79                                                                                       JPL SMAP Level 2B CAP Sea Surface Salinity V5.0 Validated Dataset
# 80                                               JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset
# 81                                                                                           RSS SMAP Level 2C Sea Surface Salinity V4.0 Validated Dataset
# 82                                                                         SWOT Simulated Level-2 KaRIn SSH from MITgcm ECCO LLC4320 for Cal/Val Version 1
# 83                                                                         SWOT Simulated Level-2 KaRIn SSH from MITgcm ECCO LLC4320 for Science Version 1
# 84                                                                                      SWOT Simulated Level-2 KaRIn SSH from GLORYS for Cal/Val Version 1
# 85                                                                         SWOT Simulated Level-2 Nadir SSH from MITgcm ECCO LLC4320 for Cal/Val Version 1
# 86                                                                         SWOT Simulated Level-2 Nadir SSH from MITgcm ECCO LLC4320 for Science Version 1
# 87                                                                                      SWOT Simulated Level-2 Nadir SSH from GLORYS for Cal/Val Version 1
# 88                                                                                      SWOT Simulated Level-2 Nadir SSH from GLORYS for Science Version 1
# 89             Monthly gridded Global Land Data Assimilation System (GLDAS) from Noah-v3.3 land hydrology model for GRACE and GRACE-FO over nominal months
# 90   GHRSST Level 2P Global Subskin Sea Surface Temperature from TRMM Microwave Imager (TMI) onboard Tropical Rainfall Measurement Mission (TRMM) satel...
# 91    GHRSST Level 2P Global Sea Surface Skin Temperature  from the Visible and Infrared Imager/Radiometer Suite (VIIRS) on the Suomi-NPP satellite (GDS2)
# 92                                                              GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V1
# 93                                                                               GHRSST NOAA/STAR GOES-17 ABI L2P America Region SST v2.71 dataset in GDS2
# 94                                                                     GHRSST NOAA/STAR Himawari-08 AHI L2P Pacific Ocean Region SST v2.70 dataset in GDS2
# 95                                                                    GHRSST NOAA/STAR Himawari-08 AHI L3C  Pacific Ocean Region SST v2.70 dataset in GDS2
# 96                                                         SARAL Near-Real-Time Value-added Operational Geophysical Data Record Sea Surface Height Anomaly
# 97                                                                                           Gridded Altimeter Fields with Enhanced Coastal Coverage Daily
# 98             GHRSST Level 3U Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 99   GHRSST Level 3U Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 100                                   Tellus Level-4 Antarctica Mass Anomaly Time Series from JPL GRACE/GRACE-FO Mascon CRI Filtered Release 06 version 02
# 101                                                                          Aquarius Official Release Level 2 Sea Surface Salinity & Wind Speed Data V5.0
# 102                                              Aquarius Official Release Level 3 Sea Surface Salinity Standard Mapped Image 7-Day Running Mean Data V5.0
# 103                                                                           MetOp-A ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 104                                                MetOp-A ASCAT Level 2 12.5-km Ocean Surface Wind Vector Climate Data Record Optimized for Coastal Ocean
# 105  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by NAVO
# 106  GHRSST Level 2P Regional 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by...
# 107                                                                               GHRSST NOAA/STAR Metop-A AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 108                                                                              GHRSST NOAA/STAR Metop-A AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 109                                                                               GHRSST NOAA/STAR Metop-B AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 110                                                                               GHRSST NOAA/STAR Metop-C AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 111                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-A satellite produced by NAVO
# 112                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-B satellite produced by NAVO
# 113                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-C satellite produced by NAVO
# 114  GHRSST L3C global sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-...
# 115                            GHRSST Level 3C North Atlantic Regional (NAR) subskin Sea Surface Temperature from Metop/AVHRR (GDS V2) produced by OSI SAF
# 116                                                                                                         CYGNSS Level 1 Climate Data Record Version 1.0
# 117                                                                                                         CYGNSS Level 1 Climate Data Record Version 1.1
# 118                                                                                                      CYGNSS Level 1 Full Delay Doppler Map Data Record
# 119                                                                                          CYGNSS Level 1 Full Delay Doppler Map Data Record Version 3.0
# 120                                                                                                  CYGNSS Level 1 Raw Intermediate Frequency Data Record
# 121                                                                                                         CYGNSS Level 1 Science Data Record Version 2.1
# 122                                                                                                         CYGNSS Level 2 Climate Data Record Version 1.0
# 123                                                                                 CYGNSS Level 2 Ocean Surface Heat Flux Science Data Record Version 1.0
# 124                                                                                                         CYGNSS Level 2 Science Data Record Version 2.1
# 125                                                                                                         CYGNSS Level 3 Climate Data Record Version 1.0
# 126                                                                                                         CYGNSS Level 3 Climate Data Record Version 1.1
# 127                                                                                                        CYGNSS L3 Ocean Microplastic Concentration V1.0
# 128                                                                                      CYGNSS Level 3 Storm Centric Grid Science Data Record Version 1.0
# 129                                                                                                       UCAR-CU CYGNSS Level 3 Soil Moisture Version 1.0
# 130                                                                                                         CYGNSS Level 3 Science Data Record Version 2.1
# 131                                                                                                         CYGNSS Level 3 Science Data Record Version 3.0
# 132                                                                                                         CYGNSS Level 3 Science Data Record Version 3.1
# 133                                                              GHRSST Level 4 DMI_OI Global Foundation Sea Surface Temperature Analysis  (GDS version 2)
# 134                                                                                                              ECCO Ancillary Data (Version 4 Release 4)
# 135                                      ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 136                                        ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# 137                                      ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# 138                                                                ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 139                                                              ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 140                                                                ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# 141                                                              ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# 142                                           ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
#
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ba1abf3caa2b> in <module>()
#      10 display(data)
#      11
# ---> 12 data.xr.read[SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXC_V1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'xr'

# %%
from platform import system
from netrc import netrc
from getpass import getpass
from urllib import request
from http.cookiejar import CookieJar
from os.path import join, expanduser

TOKEN_DATA = ("<token>"
              "<username>%s</username>"
              "<password>%s</password>"
              "<client_id>PODAAC CMR Client</client_id>"
              "<user_ip_address>%s</user_ip_address>"
              "</token>")


def setup_earthdata_login_auth(urs: str='urs.earthdata.nasa.gov', cmr: str='cmr.earthdata.nasa.gov'):

    # GET URS LOGIN INFO FROM NETRC OR USER PROMPTS:
    netrc_name = "_netrc" if system()=="Windows" else ".netrc"
    try:
        username, _, password = netrc(file=join(expanduser('~'), netrc_name)).authenticators(urs)
        print("# Your URS credentials were securely retrieved from your .netrc file.")
    except (FileNotFoundError, TypeError):
        print('# Please provide your Earthdata Login credentials for access.')
        print('# Your info will only be passed to %s and will not be exposed in Jupyter.' % (urs))
        username = input('Username: ')
        password = getpass('Password: ')

    # SET UP URS AUTHENTICATION FOR HTTP DOWNLOADS:
    manager = request.HTTPPasswordMgrWithDefaultRealm()
    manager.add_password(None, urs, username, password)
    auth = request.HTTPBasicAuthHandler(manager)
    jar = CookieJar()
    processor = request.HTTPCookieProcessor(jar)
    opener = request.build_opener(auth, processor)
    request.install_opener(opener)

    # GET TOKEN TO ACCESS RESTRICTED CMR METADATA:
    ip = requests.get("https://ipinfo.io/ip").text.strip()
    r = requests.post(
        url="https://%s/legacy-services/rest/tokens" % cmr,
        data=TOKEN_DATA % (str(username), str(password), ip),
        headers={'Content-Type': 'application/xml', 'Accept': 'application/json'}
    )
    return r.json()['token']['id']

    # Provide URS credentials for HTTP download auth & CMR token retrieval:
    _token = setup_earthdata_login_auth(urs=urs, cmr=cmr)

####### This is code from tutorials to set credentials 

#https://github.com/podaac/tutorials/blob/master/notebooks/SWOT-EA-2021/Estuary_explore_inCloud_zarr.ipynb

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#                                                       short_name  \
# 0                                        MODIS_A-JPL-L2P-v2019.0
# 1                                        MODIS_T-JPL-L2P-v2019.0
# 2                                                 ASCATB-L2-25km
# 3                                                 ASCATC-L2-25km
# 4                                       VIIRS_NPP-STAR-L3U-v2.80
# 5                                           MUR-JPL-L4-GLOB-v4.1
# 6                                       VIIRS_N20-OSPO-L2P-v2.61
# 7                                       VIIRS_NPP-OSPO-L2P-v2.61
# 8                           JASON_CS_S6A_L2_ALT_HR_STD_OST_NRT_F
# 9                                       VIIRS_N20-STAR-L3U-v2.80
# 10                                             ASCATB-L2-Coastal
# 11                                             ASCATC-L2-Coastal
# 12                                                CYGNSS_L1_V3.1
# 13                                      VIIRS_N20-OSPO-L3U-v2.61
# 14                          JASON_CS_S6A_L2_ALT_LR_STD_OST_NRT_F
# 15                                       VIIRS_NPP-NAVO-L2P-v3.0
# 16                                      VIIRS_NPP-OSPO-L3U-v2.61
# 17                                      VIIRS_N20-STAR-L2P-v2.80
# 18                                                CYGNSS_L1_V3.0
# 19                                        OSCAR_L4_OC_FINAL_V2.0
# 20                                      VIIRS_NPP-STAR-L2P-v2.80
# 21                                      AVHRRF_MB-STAR-L3U-v2.80
# 22                             AVHRR_SST_METOP_B-OSISAF-L2P-v1.0
# 23                        ECCO_L4_TEMP_SALINITY_05DEG_DAILY_V4R4
# 24                          JASON_CS_S6A_L2_ALT_LR_STD_OST_STC_F
# 25                                 SEVIRI_IO_SST-OSISAF-L3C-v1.0
# 26                                    SEVIRI_SST-OSISAF-L3C-v1.0
# 27                                        ABI_G16-STAR-L3C-v2.70
# 28                                       MUR25-JPL-L4-GLOB-v04.2
# 29                                        ABI_G16-STAR-L2P-v2.70
# 30                          JASON_CS_S6A_L2_ALT_HR_STD_OST_STC_F
# 31                          JASON_CS_S6A_L2_ALT_LR_RED_OST_NRT_F
# 32                                       OSTIA-UKMO-L4-GLOB-v2.0
# 33                                   SMAP_JPL_L2B_NRT_SSS_CAP_V5
# 34                                        ABI_G17-STAR-L3C-v2.71
# 35                                      AVHRRF_MC-STAR-L3U-v2.80
# 36                                    CMC0.1deg-CMC-L4-GLOB-v3.0
# 37                                                CYGNSS_L2_V3.1
# 38                            ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4
# 39                                  ECCO_L4_SSH_05DEG_DAILY_V4R4
# 40                      ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4
# 41                                 JASON_CS_S6A_L1B_ALT_HR_NTC_F
# 42              JASON_CS_S6A_L2_ALT_HR_STD_OST_NTC_F_UNVALIDATED
# 43              JASON_CS_S6A_L2_ALT_LR_STD_OST_NTC_F_UNVALIDATED
# 44                                      K10_SST-NAVO-L4-GLOB-v01
# 45   SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL1812
# 46                      TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
# 47                                           AMSR2-REMSS-L2P-v8a
# 48                                        AMSR2-REMSS-L2P_RT_v8a
# 49                                                ASCATA-L2-25km
# 50                                      AVHRRMTA_G-NAVO-L2P-v1.0
# 51                                      AVHRRMTB_G-NAVO-L2P-v1.0
# 52                                    AVHRR_OI-NCEI-L4-GLOB-v2.1
# 53                                            CYGNSS_L2_CDR_V1.1
# 54                               CYGNSS_L2_SURFACE_FLUX_CDR_V1.0
# 55                               CYGNSS_L2_SURFACE_FLUX_CDR_V1.1
# 56                                                CYGNSS_L2_V3.0
# 57                                 CYGNSS_NOAA_L2_SWSP_25KM_V1.1
# 58                                 CYGNSS_NOAA_L2_SWSP_25KM_V1.2
# 59                     ECCO_L4_DENS_STRAT_PRESS_05DEG_DAILY_V4R4
# 60                            ECCO_L4_OCEAN_VEL_05DEG_DAILY_V4R4
# 61               ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_DAILY_V4R4
# 62                                ECCO_L4_SSH_05DEG_MONTHLY_V4R4
# 63                                  GAMSSA_28km-ABOM-L4-GLOB-v01
# 64                               GRACEFO_L1B_ASCII_GRAV_JPL_RL04
# 65                                       JASON_3_L2_OST_OGDR_GPS
# 66                                 JASON_CS_S6A_L1A_ALT_HR_NTC_F
# 67                          JASON_CS_S6A_L2_ALT_HR_RED_OST_NRT_F
# 68                          JASON_CS_S6A_L2_ALT_HR_RED_OST_STC_F
# 69              JASON_CS_S6A_L2_ALT_LR_RED_OST_NTC_F_UNVALIDATED
# 70                          JASON_CS_S6A_L2_ALT_LR_RED_OST_STC_F
# 71                                   JASON_CS_S6A_L2_AMR_RAD_NRT
# 72                                   JASON_CS_S6A_L2_AMR_RAD_STC
# 73                  MITgcm_LLC4320_Pre-SWOT_JPL_L4_ACC_SMST_v1.0
# 74           MODIS_AQUA_L3_SST_THERMAL_DAILY_4KM_DAYTIME_V2019.0
# 75          MODIS_TERRA_L3_SST_THERMAL_DAILY_4KM_DAYTIME_V2019.0
# 76                                           MSG03-OSPO-L2P-v1.0
# 77                                 OISSS_L4_multimission_7day_v1
# 78                                          OSCAR_L4_OC_NRT_V2.0
# 79                                       SMAP_JPL_L2B_SSS_CAP_V5
# 80                       SMAP_JPL_L3_SSS_CAP_8DAY-RUNNINGMEAN_V5
# 81                                            SMAP_RSS_L2_SSS_V4
# 82            SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1
# 83           SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_SCIENCE_V1
# 84                  SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_CALVAL_V1
# 85            SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_CALVAL_V1
# 86           SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_SCIENCE_V1
# 87                  SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_CALVAL_V1
# 88                 SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_SCIENCE_V1
# 89                     TELLUS_GLDAS-NOAH-3.3_TWS-ANOMALY_MONTHLY
# 90                                              TMI-REMSS-L2P-v4
# 91                                     VIIRS_NPP-JPL-L2P-v2016.2
# 92                                       VIIRS_NPP-NAVO-L2P-v1.0
# 93                                        ABI_G17-STAR-L2P-v2.71
# 94                                        AHI_H08-STAR-L2P-v2.70
# 95                                        AHI_H08-STAR-L3C-v2.70
# 96                                     ALTIKA_SARAL_L2_OST_XOGDR
# 97                 ALT_TIDE_GAUGE_L4_OST_SLA_US_WEST_COAST_DAILY
# 98                                           AMSR2-REMSS-L3U-v8a
# 99                                        AMSR2-REMSS-L3U_RT-v8a
# 100        ANTARCTICA_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 101                                           AQUARIUS_L2_SSS_V5
# 102                      AQUARIUS_L3_SSS_SMI_7DAY-RUNNINGMEAN_V5
# 103                                            ASCATA-L2-Coastal
# 104                                        ASCATA_L2_COASTAL_CDR
# 105                                      AVHRR19_G-NAVO-L2P-v1.0
# 106                                      AVHRR19_L-NAVO-L2P-v1.0
# 107                                     AVHRRF_MA-STAR-L2P-v2.80
# 108                                     AVHRRF_MA-STAR-L3U-v2.80
# 109                                     AVHRRF_MB-STAR-L2P-v2.80
# 110                                     AVHRRF_MC-STAR-L2P-v2.80
# 111                                     AVHRRMTA_G-NAVO-L2P-v2.0
# 112                                     AVHRRMTB_G-NAVO-L2P-v2.0
# 113                                     AVHRRMTC_G-NAVO-L2P-v2.0
# 114                        AVHRR_SST_METOP_B_GLB-OSISAF-L3C-v1.0
# 115                        AVHRR_SST_METOP_B_NAR-OSISAF-L3C-v1.0
# 116                                           CYGNSS_L1_CDR_V1.0
# 117                                           CYGNSS_L1_CDR_V1.1
# 118                                           CYGNSS_L1_FULL_DDM
# 119                                      CYGNSS_L1_FULL_DDM_V3.0
# 120                                             CYGNSS_L1_RAW_IF
# 121                                               CYGNSS_L1_V2.1
# 122                                           CYGNSS_L2_CDR_V1.0
# 123                                  CYGNSS_L2_SURFACE_FLUX_V1.0
# 124                                               CYGNSS_L2_V2.1
# 125                                           CYGNSS_L3_CDR_V1.0
# 126                                           CYGNSS_L3_CDR_V1.1
# 127                                  CYGNSS_L3_MICROPLASTIC_V1.0
# 128                                               CYGNSS_L3_S1.0
# 129                                 CYGNSS_L3_SOIL_MOISTURE_V1.0
# 130                                               CYGNSS_L3_V2.1
# 131                                               CYGNSS_L3_V3.0
# 132                                               CYGNSS_L3_V3.1
# 133                                      DMI_OI-DMI-L4-GLOB-v1.0
# 134                                  ECCO_L4_ANCILLARY_DATA_V4R4
# 135                         ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4
# 136                     ECCO_L4_ATM_STATE_LLC0090GRID_DAILY_V4R4
# 137                   ECCO_L4_ATM_STATE_LLC0090GRID_MONTHLY_V4R4
# 138                               ECCO_L4_BOLUS_05DEG_DAILY_V4R4
# 139                             ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4
# 140                         ECCO_L4_BOLUS_LLC0090GRID_DAILY_V4R4
# 141                       ECCO_L4_BOLUS_LLC0090GRID_MONTHLY_V4R4
# 142                  ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4
# 143              ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_DAILY_V4R4
# 144            ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_MONTHLY_V4R4
# 145                          ECCO_L4_FRESH_FLUX_05DEG_DAILY_V4R4
# 146                        ECCO_L4_FRESH_FLUX_05DEG_MONTHLY_V4R4
# 147                    ECCO_L4_FRESH_FLUX_LLC0090GRID_DAILY_V4R4
# 148                  ECCO_L4_FRESH_FLUX_LLC0090GRID_MONTHLY_V4R4
# 149                                  ECCO_L4_GEOMETRY_05DEG_V4R4
# 150                            ECCO_L4_GEOMETRY_LLC0090GRID_V4R4
# 151                       ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4
# 152                      ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4B
# 153                          ECCO_L4_GMSL_TIME_SERIES_DAILY_V4R4
# 154                        ECCO_L4_GMSL_TIME_SERIES_MONTHLY_V4R4
# 155                           ECCO_L4_HEAT_FLUX_05DEG_DAILY_V4R4
# 156                         ECCO_L4_HEAT_FLUX_05DEG_MONTHLY_V4R4
# 157                     ECCO_L4_HEAT_FLUX_LLC0090GRID_DAILY_V4R4
# 158                   ECCO_L4_HEAT_FLUX_LLC0090GRID_MONTHLY_V4R4
# 159                   ECCO_L4_MIXED_LAYER_DEPTH_05DEG_DAILY_V4R4
# 160                 ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4
# 161             ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_DAILY_V4R4
# 162           ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_MONTHLY_V4R4
# 163                                 ECCO_L4_OBP_05DEG_DAILY_V4R4
# 164                                ECCO_L4_OBP_05DEG_DAILY_V4R4B
# 165                               ECCO_L4_OBP_05DEG_MONTHLY_V4R4
# 166                              ECCO_L4_OBP_05DEG_MONTHLY_V4R4B
# 167                           ECCO_L4_OBP_LLC0090GRID_DAILY_V4R4
# 168                          ECCO_L4_OBP_LLC0090GRID_DAILY_V4R4B
# 169                         ECCO_L4_OBP_LLC0090GRID_MONTHLY_V4R4
# 170                        ECCO_L4_OBP_LLC0090GRID_MONTHLY_V4R4B
# 171                        ECCO_L4_OBP_LLC0090GRID_SNAPSHOT_V4R4
# 172                       ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4
# 173                 ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4
# 174        ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_DAILY_V4R4
# 175      ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_MONTHLY_V4R4
# 176        ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_DAILY_V4R4
# 177      ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_MONTHLY_V4R4
# 178     ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_DAILY_V4R4
# 179   ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_MONTHLY_V4R4
# 180          ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 181        ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 182    ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_DAILY_V4R4
# 183  ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_MONTHLY_V4R4
# 184                         ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4
# 185                     ECCO_L4_OCEAN_VEL_LLC0090GRID_DAILY_V4R4
# 186                   ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4
# 187                   ECCO_L4_SBO_CORE_TIME_SERIES_SNAPSHOT_V4R4
# 188                  ECCO_L4_SBO_CORE_TIME_SERIES_SNAPSHOT_V4R4B
# 189            ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_MONTHLY_V4R4
# 190        ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_DAILY_V4R4
# 191      ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_MONTHLY_V4R4
# 192     ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_SNAPSHOT_V4R4
# 193     ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 194   ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 195       ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_DAILY_V4R4
# 196     ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
# 197                    ECCO_L4_SEA_ICE_VELOCITY_05DEG_DAILY_V4R4
# 198                  ECCO_L4_SEA_ICE_VELOCITY_05DEG_MONTHLY_V4R4
# 199              ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_DAILY_V4R4
# 200            ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_MONTHLY_V4R4
# 201           ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_SNAPSHOT_V4R4
# 202                                ECCO_L4_SSH_05DEG_DAILY_V4R4B
# 203                              ECCO_L4_SSH_05DEG_MONTHLY_V4R4B
# 204                           ECCO_L4_SSH_LLC0090GRID_DAILY_V4R4
# 205                          ECCO_L4_SSH_LLC0090GRID_DAILY_V4R4B
# 206                         ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4
# 207                        ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4B
# 208                        ECCO_L4_SSH_LLC0090GRID_SNAPSHOT_V4R4
# 209                              ECCO_L4_STRESS_05DEG_DAILY_V4R4
# 210                            ECCO_L4_STRESS_05DEG_MONTHLY_V4R4
# 211                        ECCO_L4_STRESS_LLC0090GRID_DAILY_V4R4
# 212                      ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4
# 213                 ECCO_L4_TEMP_SALINITY_LLC0090GRID_DAILY_V4R4
# 214               ECCO_L4_TEMP_SALINITY_LLC0090GRID_MONTHLY_V4R4
# 215              ECCO_L4_TEMP_SALINITY_LLC0090GRID_SNAPSHOT_V4R4
# 216                                           EWSG1-NAVO-L2P-v01
# 217                                          GMI-REMSS-L3U-v8.2a
# 218                                         GOES15-OSPO-L2P-v1.0
# 219                                   GOES16-SST-OSISAF-L3C-v1.0
# 220                              GRACEFO_L1A_ASCII_GRAV_JPL_RL04
# 221                                  GRACEFO_L2_CSR_MONTHLY_0060
# 222                                  GRACEFO_L2_GFZ_MONTHLY_0060
# 223                                  GRACEFO_L2_JPL_MONTHLY_0060
# 224                                    GRACE_AOD1B_GRAV_GFZ_RL06
# 225                         GRC-GFO_GRIDDED_AOD1B_JPL_1-DEG_RL06
# 226                        GRC-GFO_GRIDDED_AOD1B_JPL_MASCON_RL06
# 227         GREENLAND_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 228                          Geo_Polar_Blended-OSPO-L4-GLOB-v1.0
# 229                    Geo_Polar_Blended_Night-OSPO-L4-GLOB-v1.0
# 230                             IASI_SST_METOP_B-OSISAF-L2P-v1.0
# 231                                JASON_CS_S6A_L1A_ALT_HR_STC_F
# 232                                JASON_CS_S6A_L1B_ALT_HR_STC_F
# 233                                JASON_CS_S6A_L1B_ALT_LR_NTC_F
# 234                                JASON_CS_S6A_L1B_ALT_LR_STC_F
# 235                          JASON_CS_S6A_L1B_GNSS_RO_POD_HOURLY
# 236                         JASON_CS_S6A_L2_ALT_HR_RED_OST_NTC_F
# 237             JASON_CS_S6A_L2_ALT_HR_RED_OST_NTC_F_UNVALIDATED
# 238                         JASON_CS_S6A_L2_ALT_HR_STD_OST_NTC_F
# 239                         JASON_CS_S6A_L2_ALT_LR_RED_OST_NTC_F
# 240                         JASON_CS_S6A_L2_ALT_LR_STD_OST_NTC_F
# 241                                  JASON_CS_S6A_L2_AMR_RAD_NTC
# 242                      JASON_CS_S6A_L2_AMR_RAD_NTC_UNVALIDATED
# 243                                        L3S_LEO_AM-STAR-v2.80
# 244                                        L3S_LEO_PM-STAR-v2.80
# 245                                MERGED_TP_J1_OSTM_OST_ALL_V51
# 246                             MERGED_TP_J1_OSTM_OST_CYCLES_V51
# 247                         MERGED_TP_J1_OSTM_OST_GMSL_ASCII_V51
# 248               MITgcm_LLC4320_Pre-SWOT_JPL_L4_BassStrait_v1.0
# 249                   MITgcm_LLC4320_Pre-SWOT_JPL_L4_Boknis_v1.0
# 250                MITgcm_LLC4320_Pre-SWOT_JPL_L4_CapeBasin_v1.0
# 251             MITgcm_LLC4320_Pre-SWOT_JPL_L4_GotlandBasin_v1.0
# 252              MITgcm_LLC4320_Pre-SWOT_JPL_L4_LabradorSea_v1.0
# 253               MITgcm_LLC4320_Pre-SWOT_JPL_L4_MarmaraSea_v1.0
# 254              MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWAustralia_v1.0
# 255                MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWPacific_v1.0
# 256             MITgcm_LLC4320_Pre-SWOT_JPL_L4_NewCaledonia_v1.0
# 257                 MITgcm_LLC4320_Pre-SWOT_JPL_L4_ROAM_MIZ_v1.0
# 258            MITgcm_LLC4320_Pre-SWOT_JPL_L4_RockallTrough_v1.0
# 259             MITgcm_LLC4320_Pre-SWOT_JPL_L4_WestAtlantic_v1.0
# 260               MITgcm_LLC4320_Pre-SWOT_JPL_L4_WesternMed_v1.0
# 261                  MITgcm_LLC4320_Pre-SWOT_JPL_L4_Yongala_v1.0
# 262          MODIS_AQUA_L3_SST_MID-IR_8DAY_4KM_NIGHTTIME_V2019.0
# 263          MODIS_AQUA_L3_SST_MID-IR_8DAY_9KM_NIGHTTIME_V2019.0
# 264        MODIS_AQUA_L3_SST_MID-IR_ANNUAL_4KM_NIGHTTIME_V2019.0
# 265        MODIS_AQUA_L3_SST_MID-IR_ANNUAL_9KM_NIGHTTIME_V2019.0
# 266         MODIS_AQUA_L3_SST_MID-IR_DAILY_4KM_NIGHTTIME_V2019.0
# 267         MODIS_AQUA_L3_SST_MID-IR_DAILY_9KM_NIGHTTIME_V2019.0
# 268       MODIS_AQUA_L3_SST_MID-IR_MONTHLY_4KM_NIGHTTIME_V2019.0
# 269       MODIS_AQUA_L3_SST_MID-IR_MONTHLY_9KM_NIGHTTIME_V2019.0
# 270           MODIS_AQUA_L3_SST_THERMAL_8DAY_4KM_DAYTIME_V2019.0
# 271         MODIS_AQUA_L3_SST_THERMAL_8DAY_4KM_NIGHTTIME_V2019.0
# 272           MODIS_AQUA_L3_SST_THERMAL_8DAY_9KM_DAYTIME_V2019.0
# 273         MODIS_AQUA_L3_SST_THERMAL_8DAY_9KM_NIGHTTIME_V2019.0
# 274         MODIS_AQUA_L3_SST_THERMAL_ANNUAL_4KM_DAYTIME_V2019.0
# 275       MODIS_AQUA_L3_SST_THERMAL_ANNUAL_4KM_NIGHTTIME_V2019.0
# 276         MODIS_AQUA_L3_SST_THERMAL_ANNUAL_9KM_DAYTIME_V2019.0
# 277       MODIS_AQUA_L3_SST_THERMAL_ANNUAL_9KM_NIGHTTIME_V2019.0
# 278        MODIS_AQUA_L3_SST_THERMAL_DAILY_4KM_NIGHTTIME_V2019.0
# 279          MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# 280        MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_NIGHTTIME_V2019.0
# 281        MODIS_AQUA_L3_SST_THERMAL_MONTHLY_4KM_DAYTIME_V2019.0
# 282      MODIS_AQUA_L3_SST_THERMAL_MONTHLY_4KM_NIGHTTIME_V2019.0
# 283        MODIS_AQUA_L3_SST_THERMAL_MONTHLY_9KM_DAYTIME_V2019.0
# 284      MODIS_AQUA_L3_SST_THERMAL_MONTHLY_9KM_NIGHTTIME_V2019.0
# 285         MODIS_TERRA_L3_SST_MID-IR_8DAY_4KM_NIGHTTIME_V2019.0
# 286         MODIS_TERRA_L3_SST_MID-IR_8DAY_9KM_NIGHTTIME_V2019.0
# 287       MODIS_TERRA_L3_SST_MID-IR_ANNUAL_4KM_NIGHTTIME_V2019.0
# 288       MODIS_TERRA_L3_SST_MID-IR_ANNUAL_9KM_NIGHTTIME_V2019.0
# 289        MODIS_TERRA_L3_SST_MID-IR_DAILY_4KM_NIGHTTIME_V2019.0
# 290        MODIS_TERRA_L3_SST_MID-IR_DAILY_9KM_NIGHTTIME_V2019.0
# 291      MODIS_TERRA_L3_SST_MID-IR_MONTHLY_4KM_NIGHTTIME_V2019.0
# 292      MODIS_TERRA_L3_SST_MID-IR_MONTHLY_9KM_NIGHTTIME_V2019.0
# 293          MODIS_TERRA_L3_SST_THERMAL_8DAY_4KM_DAYTIME_V2019.0
# 294        MODIS_TERRA_L3_SST_THERMAL_8DAY_4KM_NIGHTTIME_V2019.0
# 295          MODIS_TERRA_L3_SST_THERMAL_8DAY_9KM_DAYTIME_V2019.0
# 296        MODIS_TERRA_L3_SST_THERMAL_8DAY_9KM_NIGHTTIME_V2019.0
# 297        MODIS_TERRA_L3_SST_THERMAL_ANNUAL_4KM_DAYTIME_V2019.0
# 298      MODIS_TERRA_L3_SST_THERMAL_ANNUAL_4KM_NIGHTTIME_V2019.0
# 299        MODIS_TERRA_L3_SST_THERMAL_ANNUAL_9KM_DAYTIME_V2019.0
# 300      MODIS_TERRA_L3_SST_THERMAL_ANNUAL_9KM_NIGHTTIME_V2019.0
# 301       MODIS_TERRA_L3_SST_THERMAL_DAILY_4KM_NIGHTTIME_V2019.0
# 302         MODIS_TERRA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# 303       MODIS_TERRA_L3_SST_THERMAL_DAILY_9KM_NIGHTTIME_V2019.0
# 304       MODIS_TERRA_L3_SST_THERMAL_MONTHLY_4KM_DAYTIME_V2019.0
# 305     MODIS_TERRA_L3_SST_THERMAL_MONTHLY_4KM_NIGHTTIME_V2019.0
# 306       MODIS_TERRA_L3_SST_THERMAL_MONTHLY_9KM_DAYTIME_V2019.0
# 307     MODIS_TERRA_L3_SST_THERMAL_MONTHLY_9KM_NIGHTTIME_V2019.0
# 308                                  MW_IR_OI-REMSS-L4-GLOB-v5.0
# 309                                     MW_OI-REMSS-L4-GLOB-v5.0
# 310             OCEAN_MASS_TELLUS_MASCON_CRI_TIME_SERIES_RL06_V2
# 311                             OISSS_L4_multimission_monthly_v1
# 312                                 OISST_HR_NRT-GOS-L4-BLK-v2.0
# 313                                 OISST_HR_NRT-GOS-L4-MED-v2.0
# 314                                OISST_UHR_NRT-GOS-L4-BLK-v2.0
# 315                                OISST_UHR_NRT-GOS-L4-MED-v2.0
# 316                            OS2_OSCAT_LEVEL_2B_OWV_COMP_12_V2
# 317                                     OSCAR_L4_OC_INTERIM_V2.0
# 318     PRESWOT_HYDRO_GRRATS_L2_DAILY_VIRTUAL_STATION_HEIGHTS_V2
# 319           PRESWOT_HYDRO_GRRATS_L2_VIRTUAL_STATION_HEIGHTS_V2
# 320                       PRESWOT_HYDRO_L2_GREALM_LAKE_HEIGHT_V2
# 321                       PRESWOT_HYDRO_L3_LAKE_RESEVOIR_AREA_V2
# 322                 PRESWOT_HYDRO_L4_LAKE_STORAGE_TIME_SERIES_V2
# 323                   QSCAT_LEVEL_2B_OWV_COMP_12_KUSST_LCRES_4.1
# 324                           QSCAT_LEVEL_2B_OWV_COMP_12_LCR_3.1
# 325                                  RAMSSA_09km-ABOM-L4-AUS-v01
# 326                                  REYNOLDS_NCDC_L4_MONTHLY_V5
# 327                                RSCAT_LEVEL_2B_OWV_CLIM_12_V2
# 328                                          SEAGLIDER_GUAM_2019
# 329                                SEVIRI_SST_DR-OSISAF-L3C-v1.0
# 330                               SMAP_JPL_L3_SSS_CAP_MONTHLY_V5
# 331                      SMAP_RSS_L3_SSS_SMI_8DAY-RUNNINGMEAN_V4
# 332                               SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
# 333                                     SWOT_PRELAUNCH_L2_BPR_V1
# 334                                  SWOT_PRELAUNCH_L2_GLIDER_V1
# 335                                     SWOT_PRELAUNCH_L2_GPS_V1
# 336                                    SWOT_PRELAUNCH_L2_PIES_V1
# 337                                 SWOT_PRELAUNCH_L2_PRAWLER_V1
# 338                                  SWOT_PRELAUNCH_L2_SIOCTD_V1
# 339                                 SWOT_PRELAUNCH_L2_WHOICTD_V1
# 340                                      SWOT_PRELAUNCH_L2_WW_V1
# 341                SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_SCIENCE_V1
# 342                  SWOT_SIMULATED_NA_CONTINENT_L2_HR_LAKESP_V1
# 343                 SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXCVEC_V1
# 344                    SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXC_V1
# 345                  SWOT_SIMULATED_NA_CONTINENT_L2_HR_RASTER_V1
# 346                 SWOT_SIMULATED_NA_CONTINENT_L2_HR_RIVERSP_V1
# 347                         TELLUS_GRAC-GRFO_MASCON_GRID_RL06_V2
# 348                                      VIIRS_NPP-NAVO-L2P-v2.0
# 349                            VIIRS_SST_NPP_NAR-OSISAF-L3C-v1.0
# 350                                    WindSat-REMSS-L3U-v7.0.1a
#
#                                                                                                                                                  long_name  \
# 0     GHRSST Level 2P Global Sea Surface Skin Temperature from the Moderate Resolution Imaging Spectroradiometer (MODIS) on the NASA Aqua satellite (GDS2)
# 1    GHRSST Level 2P Global Sea Surface Skin Temperature from the Moderate Resolution Imaging Spectroradiometer (MODIS) on the NASA Terra satellite (GDS2)
# 2                                                                              MetOp-B ASCAT Level 2 25.0km Ocean Surface Wind Vectors in Full Orbit Swath
# 3                                                                              MetOp-C ASCAT Level 2 25.0km Ocean Surface Wind Vectors in Full Orbit Swath
# 4                                                                                        GHRSST Level 3U NOAA STAR SST v2.80 from VIIRS on S-NPP Satellite
# 5                                                                             GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 6                                                                          GHRSST Level 2P OSPO dataset v2.61 from VIIRS on the NOAA-20 satellite (GDS v2)
# 7                                                                                GHRSST Level 2P OSPO dataset v2.61 from VIIRS on S-NPP Satellite (GDS v2)
# 8                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NRT Ocean Surface Topography
# 9                                                                                      GHRSST Level 3U NOAA STAR SST v2.80 from VIIRS on NOAA-20 Satellite
# 10                                                                            MetOp-B ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 11                                                                            MetOp-C ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 12                                                                                                          CYGNSS Level 1 Science Data Record Version 3.1
# 13                                                                             GHRSST Level 3U OSPO dataset v2.61 from VIIRS on NOAA-20 Satellite (GDS v2)
# 14                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NRT Ocean Surface Topography
# 15   GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 16                                                                               GHRSST Level 3U OSPO dataset v2.61 from VIIRS on S-NPP Satellite (GDS v2)
# 17                                                                                    GHRSST Level 2P NOAA STAR SST  v2.80 from VIIRS on NOAA-20 Satellite
# 18                                                                                                          CYGNSS Level 1 Science Data Record Version 3.0
# 19                                                     Ocean Surface Current Analyses Real-time (OSCAR) Surface Currents - Final 0.25 Degree (Version 2.0)
# 20                                                                                       GHRSST Level 2P NOAA STAR SST v2.80 from VIIRS on S-NPP Satellite
# 21                                                                               GHRSST NOAA/STAR Metop-B AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 22   GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 23                                                                       ECCO Ocean Temperature and Salinity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 24                                                                Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) STC Ocean Surface Topography
# 25   GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 26   GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
# 27                                                                              GHRSST NOAA/STAR GOES-16 ABI  L3C America Region SST v2.70 dataset in GDS2
# 28                                                                    GHRSST Level 4 MUR 0.25deg Global Foundation Sea Surface Temperature Analysis (v4.2)
# 29                                                                               GHRSST NOAA/STAR GOES-16 ABI L2P America Region SST v2.70 dataset in GDS2
# 30                                                               Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) STC Ocean Surface Topography
# 31                                                        Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NRT Reduced Ocean Surface Topography
# 32                                                                 GHRSST Level 4 OSTIA Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 33                                                                        JPL SMAP Level 2B Near Real-time CAP Sea Surface Salinity V5.0 Validated Dataset
# 34                                                                              GHRSST NOAA/STAR GOES-17 ABI  L3C America Region SST v2.71 dataset in GDS2
# 35                                                                               GHRSST NOAA/STAR Metop-C AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 36                                                             GHRSST Level 4 CMC0.1deg Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 37                                                                                                          CYGNSS Level 2 Science Data Record Version 3.1
# 38                                         ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# 39                                                                                   ECCO Sea Surface Height - Daily Mean 0.5 Degree (Version 4 Release 4)
# 40                                                                     ECCO Ocean Temperature and Salinity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 41                                                                  Sentinel-6A MF Jason-CS L1B P4 Altimeter High Resolution (HR) NTC Geolocated Waveforms
# 42                                                 Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NTC Ocean Surface Topography (Unvalidated)
# 43                                                  Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NTC Ocean Surface Topography (Unvalidated)
# 44                                   GHRSST Level 4 K10_SST Global 10 km Analyzed Sea Surface Temperature from Naval Oceanographic Office (NAVO) in GDS2.0
# 45                                                                                              MEaSUREs Gridded Sea Surface Height Anomalies Version 1812
# 46     JPL GRACE and GRACE-FO Mascon Ocean, Ice, and Hydrology Equivalent Water Height Coastal Resolution Improvement (CRI) Filtered Release 06 Version 02
# 47             GHRSST Level 2P Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 48   GHRSST Level 2P Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 49                                                                                                MetOp-A ASCAT Level 2 25.0 km Ocean Surface Wind Vectors
# 50   GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-A satellite produced by NAVO
# 51   GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-B satellite produced by NAVO
# 52                                                                GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# 53                                                                                                          CYGNSS Level 2 Climate Data Record Version 1.1
# 54                                                                                  CYGNSS Level 2 Ocean Surface Heat Flux Climate Data Record Version 1.0
# 55                                                                                  CYGNSS Level 2 Ocean Surface Heat Flux Climate Data Record Version 1.1
# 56                                                                                                          CYGNSS Level 2 Science Data Record Version 3.0
# 57                                                                                        NOAA CYGNSS Level 2 Science Wind Speed 25-km Product Version 1.1
# 58                                                                                        NOAA CYGNSS Level 2 Science Wind Speed 25-km Product Version 1.2
# 59                                              ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# 60                                                                                       ECCO Ocean Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 61                                                         ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean 0.5 Degree (Version 4 Release 4)
# 62                                                                                 ECCO Sea Surface Height - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 63                                                       GHRSST Level 4 GAMSSA_28km Global Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 64                                                                                                 GRACE-FO Level-1B Release version 4.0 from JPL in ASCII
# 65                                                                                                                   Jason-3 GPS based orbit and SSHA OGDR
# 66                                     Sentinel-6A MF Jason-CS L1A P4 Altimeter High Resolution (HR) NTC Intermediate Outputs with Instrument Calibrations
# 67                                                       Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) NRT Reduced Ocean Surface Topography
# 68                                                       Sentinel-6A MF Jason-CS L2 P4 Altimeter High Resolution (HR) STC Reduced Ocean Surface Topography
# 69                                          Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) NTC Reduced Ocean Surface Topography (Unvalidated)
# 70                                                        Sentinel-6A MF Jason-CS L2 P4 Altimeter Low Resolution (LR) STC Reduced Ocean Surface Topography
# 71                                                             Sentinel-6A MF Jason-CS L2 Advanced Microwave Radiometer (AMR-C) NRT Geophysical Parameters
# 72                                                             Sentinel-6A MF Jason-CS L2 Advanced Microwave Radiometer (AMR-C) STC Geophysical Parameters
# 73                                                 Southern Ocean Pre-SWOT Level-4 Hourly MITgcm LLC4320 Native Grid 2km Oceanographic Dataset Version 1.0
# 74                                                                                            MODIS Aqua Level 3 SST Thermal IR  Daily 4km Daytime V2019.0
# 75                                                                                            MODIS Terra Level 3 SST Thermal IR Daily 4km Daytime V2019.0
# 76   GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Sec...
# 77                                                                             Multi-Mission Optimally Interpolated Sea Surface Salinity Global Dataset V1
# 78                                            Ocean Surface Current Analyses Real-time (OSCAR) Surface Currents - Near Real Time 0.25 Degree (Version 2.0)
# 79                                                                                       JPL SMAP Level 2B CAP Sea Surface Salinity V5.0 Validated Dataset
# 80                                               JPL SMAP Level 3 CAP Sea Surface Salinity Standard Mapped Image 8-Day Running Mean V5.0 Validated Dataset
# 81                                                                                           RSS SMAP Level 2C Sea Surface Salinity V4.0 Validated Dataset
# 82                                                                         SWOT Simulated Level-2 KaRIn SSH from MITgcm ECCO LLC4320 for Cal/Val Version 1
# 83                                                                         SWOT Simulated Level-2 KaRIn SSH from MITgcm ECCO LLC4320 for Science Version 1
# 84                                                                                      SWOT Simulated Level-2 KaRIn SSH from GLORYS for Cal/Val Version 1
# 85                                                                         SWOT Simulated Level-2 Nadir SSH from MITgcm ECCO LLC4320 for Cal/Val Version 1
# 86                                                                         SWOT Simulated Level-2 Nadir SSH from MITgcm ECCO LLC4320 for Science Version 1
# 87                                                                                      SWOT Simulated Level-2 Nadir SSH from GLORYS for Cal/Val Version 1
# 88                                                                                      SWOT Simulated Level-2 Nadir SSH from GLORYS for Science Version 1
# 89             Monthly gridded Global Land Data Assimilation System (GLDAS) from Noah-v3.3 land hydrology model for GRACE and GRACE-FO over nominal months
# 90   GHRSST Level 2P Global Subskin Sea Surface Temperature from TRMM Microwave Imager (TMI) onboard Tropical Rainfall Measurement Mission (TRMM) satel...
# 91    GHRSST Level 2P Global Sea Surface Skin Temperature  from the Visible and Infrared Imager/Radiometer Suite (VIIRS) on the Suomi-NPP satellite (GDS2)
# 92                                                              GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V1
# 93                                                                               GHRSST NOAA/STAR GOES-17 ABI L2P America Region SST v2.71 dataset in GDS2
# 94                                                                     GHRSST NOAA/STAR Himawari-08 AHI L2P Pacific Ocean Region SST v2.70 dataset in GDS2
# 95                                                                    GHRSST NOAA/STAR Himawari-08 AHI L3C  Pacific Ocean Region SST v2.70 dataset in GDS2
# 96                                                         SARAL Near-Real-Time Value-added Operational Geophysical Data Record Sea Surface Height Anomaly
# 97                                                                                           Gridded Altimeter Fields with Enhanced Coastal Coverage Daily
# 98             GHRSST Level 3U Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 99   GHRSST Level 3U Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 100                                   Tellus Level-4 Antarctica Mass Anomaly Time Series from JPL GRACE/GRACE-FO Mascon CRI Filtered Release 06 version 02
# 101                                                                          Aquarius Official Release Level 2 Sea Surface Salinity & Wind Speed Data V5.0
# 102                                              Aquarius Official Release Level 3 Sea Surface Salinity Standard Mapped Image 7-Day Running Mean Data V5.0
# 103                                                                           MetOp-A ASCAT Level 2 Ocean Surface Wind Vectors Optimized for Coastal Ocean
# 104                                                MetOp-A ASCAT Level 2 12.5-km Ocean Surface Wind Vector Climate Data Record Optimized for Coastal Ocean
# 105  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by NAVO
# 106  GHRSST Level 2P Regional 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by...
# 107                                                                               GHRSST NOAA/STAR Metop-A AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 108                                                                              GHRSST NOAA/STAR Metop-A AVHRR FRAC ACSPO v2.80 0.02 L3U Dataset (GDS v2)
# 109                                                                               GHRSST NOAA/STAR Metop-B AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 110                                                                               GHRSST NOAA/STAR Metop-C AVHRR FRAC ACSPO v2.80 1km L2P Dataset (GDS v2)
# 111                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-A satellite produced by NAVO
# 112                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-B satellite produced by NAVO
# 113                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-C satellite produced by NAVO
# 114  GHRSST L3C global sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-...
# 115                            GHRSST Level 3C North Atlantic Regional (NAR) subskin Sea Surface Temperature from Metop/AVHRR (GDS V2) produced by OSI SAF
# 116                                                                                                         CYGNSS Level 1 Climate Data Record Version 1.0
# 117                                                                                                         CYGNSS Level 1 Climate Data Record Version 1.1
# 118                                                                                                      CYGNSS Level 1 Full Delay Doppler Map Data Record
# 119                                                                                          CYGNSS Level 1 Full Delay Doppler Map Data Record Version 3.0
# 120                                                                                                  CYGNSS Level 1 Raw Intermediate Frequency Data Record
# 121                                                                                                         CYGNSS Level 1 Science Data Record Version 2.1
# 122                                                                                                         CYGNSS Level 2 Climate Data Record Version 1.0
# 123                                                                                 CYGNSS Level 2 Ocean Surface Heat Flux Science Data Record Version 1.0
# 124                                                                                                         CYGNSS Level 2 Science Data Record Version 2.1
# 125                                                                                                         CYGNSS Level 3 Climate Data Record Version 1.0
# 126                                                                                                         CYGNSS Level 3 Climate Data Record Version 1.1
# 127                                                                                                        CYGNSS L3 Ocean Microplastic Concentration V1.0
# 128                                                                                      CYGNSS Level 3 Storm Centric Grid Science Data Record Version 1.0
# 129                                                                                                       UCAR-CU CYGNSS Level 3 Soil Moisture Version 1.0
# 130                                                                                                         CYGNSS Level 3 Science Data Record Version 2.1
# 131                                                                                                         CYGNSS Level 3 Science Data Record Version 3.0
# 132                                                                                                         CYGNSS Level 3 Science Data Record Version 3.1
# 133                                                              GHRSST Level 4 DMI_OI Global Foundation Sea Surface Temperature Analysis  (GDS version 2)
# 134                                                                                                              ECCO Ancillary Data (Version 4 Release 4)
# 135                                      ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 136                                        ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# 137                                      ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# 138                                                                ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 139                                                              ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 140                                                                ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# 141                                                              ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# 142                                           ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 143                                             ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# 144                                           ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# 145                                                         ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean 0.5 Degree (Version 4 Release 4)
# 146                                                       ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 147                                                         ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# 148                                                       ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# 149                                                                   ECCO Geometry Parameters for the 0.5 degree Lat-Lon Model Grid (Version 4 Release 4)
# 150                                                        ECCO Geometry Parameters for the Lat-Lon-Cap 90 (llc90) Native Model Grid (Version 4 Release 4)
# ...
# 346  C2263384307-POCLOUD  2022-08-01     2022-08-22
# 347  C2036882434-POCLOUD  2002-04-04  [NaT/Present]
# 348  C2036881016-POCLOUD  2016-02-25     2018-02-22
# 349  C2036878808-POCLOUD  2013-11-11  [NaT/Present]
# 350  C2036878925-POCLOUD  2002-06-01     2020-10-19

# %%
# Calling short name to collect metadata
grace_ShortName = "TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2"
grace_ShortName
# Out:
# 'TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2'

# %%
#### THIS LINK BELOW IS EXAMPLES GOOOOOOOOOD
#https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html#json



#### THIS LINK BELOW IS EXAMPLES GOOOOOOOOOD
#https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html#json

# %%
# Collect dataset
#r = requests.get(url="https://cmr.earthdata.nasa.gov/search/collections.umm_json", 


# find collection by short name
# !curl "https://cmr.earthdata.nasa.gov/search/collections?provider_short_name\[\]=SHORT_5&options\[provider_short_name\]\[ignore_case\]=true"
# Out:
# <?xml version="1.0" encoding="UTF-8"?><results><hits>0</hits><took>12</took><references></references></results>

# %% [markdown]
# Find collections by entry id

# %%
# !curl "https://cmr.earthdata.nasa.gov/search/collections?entry_id\[\]=SHORT_V5"
# Out:
# <?xml version="1.0" encoding="UTF-8"?><results><hits>0</hits><took>17</took><references></references></results>

# %% [markdown]
# ---
#
#
#
# ---

# %%
# !curl "https://cmr.earthdata.nasa.gov/search/collections?downloadable=true"
# Out:
# <?xml version="1.0" encoding="UTF-8"?><results><hits>39913</hits><took>21</took><references><reference><name>"The Omnivores Dilemma": The Effect of Autumn Diet on Winter Physiology and Condition of Juvenile Antarctic Krill</name><id>C1934541400-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1934541400-SCIOPS/2</location><revision-id>2</revision-id></reference><reference><name>0.5 hour 1 M HCl extraction data for the Windmill Islands marine sediments</name><id>C1214305813-AU_AADC</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214305813-AU_AADC/11</location><revision-id>11</revision-id></reference><reference><name>1-100Hz ULF/ELF Electromagnetic Wave Observation at Syowa Station</name><id>C1214590112-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214590112-SCIOPS/7</location><revision-id>7</revision-id></reference><reference><name>10 m firn temperature data: LGB traverses 1990-95</name><id>C1214313574-AU_AADC</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214313574-AU_AADC/10</location><revision-id>10</revision-id></reference><reference><name>10 sec GPS ground tracking data</name><id>C1214586614-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214586614-SCIOPS/4</location><revision-id>4</revision-id></reference><reference><name>10 year trend of levels of organochlorine pollutants in Antarctic seabirds</name><id>C1214305884-AU_AADC</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214305884-AU_AADC/11</location><revision-id>11</revision-id></reference><reference><name>12 Hourly Interpolated Surface Air Pressure from Buoys</name><id>C1214600618-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214600618-SCIOPS/3</location><revision-id>3</revision-id></reference><reference><name>12,000 year record of sea spray and minerogenic input from Emerald Lake, Macquarie Island</name><id>C2102891784-AU_AADC</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C2102891784-AU_AADC/2</location><revision-id>2</revision-id></reference><reference><name>12-Hourly Interpolated Surface Position from Buoys</name><id>C1214600619-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214600619-SCIOPS/4</location><revision-id>4</revision-id></reference><reference><name>12-Hourly Interpolated Surface Velocity from Buoys</name><id>C1214600621-SCIOPS</id><location>https://cmr.earthdata.nasa.gov:443/search/concepts/C1214600621-SCIOPS/4</location><revision-id>4</revision-id></reference></references></results>

# %%
(https://cmr.earthdata.nasa.gov:443/search/concepts/G550016-GHRC)
<OnlineResource>
    <URL>http://ghrc.nsstc.nasa.gov/opendap/ssmi/f14/monthly/</URL>
    <Type>OPeNDAP</Type>
</OnlineResource>

# %%
# !curl https://cmr.earthdata.nasa.gov:443/search/concepts/G550016-GHRC.atom
 
    <link href="http://ghrc.nsstc.nasa.gov/opendap/ssmi/f14/monthly/" hreflang="en-US" title="(OPeNDAP)" rel="http://esipfed.org/ns/fedsearch/1.1/data#"></link>
# Out:
#   File "<ipython-input-61-57559ad7105b>", line 3
#     <link href="http://ghrc.nsstc.nasa.gov/opendap/ssmi/f14/monthly/" hreflang="en-US" title="(OPeNDAP)" rel="http://esipfed.org/ns/fedsearch/1.1/data#"></link>
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# entry_title
# dataset_id - alias for entry_title
# short_name
# entry_id
# start_date
# end_date
# platform
# instrument
# sensor
# provider
# revision_date
# score - document relevance score, defaults to descending. See Document Scoring.
# has_granules - Sorts collections by whether they have granules or not. Collections with granules are sorted before collections without granules.
# has_granules_or_cwic - Sorts collections by whether they have granules or CWIC consortium. Collections with granules or CWIC consortium are sorted before collections without granules or a CWIC consortium.
# usage_score - Sorts collection by usage. The usage score comes from the EMS metrics, which are ingested into the CMR.
# ongoing - Sorts collection by fuzzy collection end-date in relation to ongoing-days configured. Any end-date after today, minus the configured ongoing-days (30 by default), is considered ongoing. Any end-date before that is not ongoing.
# Examples of sorting by start_date in descending(Most recent data first) and ascending orders(Note: the + must be escaped with %2B):
#
# curl "https://cmr.earthdata.nasa.gov/search/collections?sort_key\[\]=-start_date"
# curl "https://cmr.earthdata.nasa.gov/search/collections?sort_key\[\]=%2Bstart_date"

# %%
# !pip install requests
# !pip install s3fs
# !pip install awscli
# !pip install --upgrade s3fs
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.28.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2022.6.15)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting s3fs
#   Downloading s3fs-2022.5.0-py3-none-any.whl (27 kB)
# Collecting aiobotocore~=2.3.0
#   Downloading aiobotocore-2.3.3.tar.gz (65 kB)
#      |████████████████████████████████| 65 kB 2.4 MB/s
# Collecting aiohttp<=4
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 30.8 MB/s
# Collecting fsspec==2022.5.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 42.4 MB/s
# Collecting botocore<1.24.22,>=1.24.21
#   Downloading botocore-1.24.21-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 15.7 MB/s
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.7/dist-packages (from aiobotocore~=2.3.0->s3fs) (1.14.1)
# Collecting aioitertools>=0.5.1
#   Downloading aioitertools-0.10.0-py3-none-any.whl (23 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (21.4.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 35.7 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 37.9 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (4.1.1)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.0 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (2.0.12)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 61.3 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp<=4->s3fs) (2.10)
# Building wheels for collected packages: aiobotocore
#   Building wheel for aiobotocore (setup.py) ... done
#   Created wheel for aiobotocore: filename=aiobotocore-2.3.3-py3-none-any.whl size=64640 sha256=cab8f76703027d8d7b23036827dfbc51bfa846dff4a101812eee6eda7ad16b75
#   Stored in directory: /root/.cache/pip/wheels/71/90/2f/bf0c130857587a589d0faa0fb743a7e52b915037532008aabe
# Successfully built aiobotocore
# Installing collected packages: multidict, frozenlist, yarl, urllib3, jmespath, asynctest, async-timeout, aiosignal, botocore, aioitertools, aiohttp, fsspec, aiobotocore, s3fs
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiobotocore-2.3.3 aiohttp-3.8.1 aioitertools-0.10.0 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 botocore-1.24.21 frozenlist-1.3.0 fsspec-2022.5.0 jmespath-1.0.1 multidict-6.0.2 s3fs-2022.5.0 urllib3-1.26.9 yarl-1.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting awscli
#   Downloading awscli-1.25.17-py3-none-any.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 4.1 MB/s
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /usr/local/lib/python3.7/dist-packages (from awscli) (3.13)
# Collecting docutils<0.17,>=0.10
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 49.0 MB/s
# Collecting rsa<4.8,>=3.1.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.2 MB/s
# Collecting colorama<0.4.5,>=0.2.5
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting botocore==1.27.17
#   Downloading botocore-1.27.17-py3-none-any.whl (8.9 MB)
#      |████████████████████████████████| 8.9 MB 54.5 MB/s
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore==1.27.17->awscli) (1.26.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from botocore==1.27.17->awscli) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore==1.27.17->awscli) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.27.17->awscli) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<4.8,>=3.1.2->awscli) (0.4.8)
# Installing collected packages: botocore, s3transfer, rsa, docutils, colorama, awscli
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.24.21
#     Uninstalling botocore-1.24.21:
#       Successfully uninstalled botocore-1.24.21
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# aiobotocore 2.3.3 requires botocore<1.24.22,>=1.24.21, but you have botocore 1.27.17 which is incompatible.
# Successfully installed awscli-1.25.17 botocore-1.27.17 colorama-0.4.4 docutils-0.16 rsa-4.7.2 s3transfer-0.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: s3fs in /usr/local/lib/python3.7/dist-packages (2022.5.0)
# Requirement already satisfied: fsspec==2022.5.0 in /usr/local/lib/python3.7/dist-packages (from s3fs) (2022.5.0)
# Requirement already satisfied: aiobotocore~=2.3.0 in /usr/local/lib/python3.7/dist-packages (from s3fs) (2.3.3)
# Requirement already satisfied: aiohttp<=4 in /usr/local/lib/python3.7/dist-packages (from s3fs) (3.8.1)
# Collecting botocore<1.24.22,>=1.24.21
#   Using cached botocore-1.24.21-py3-none-any.whl (8.6 MB)
# Requirement already satisfied: aioitertools>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from aiobotocore~=2.3.0->s3fs) (0.10.0)
# Requirement already satisfied: wrapt>=1.10.10 in /usr/local/lib/python3.7/dist-packages (from aiobotocore~=2.3.0->s3fs) (1.14.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (4.1.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp<=4->s3fs) (6.0.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (1.26.9)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.24.22,>=1.24.21->aiobotocore~=2.3.0->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp<=4->s3fs) (2.10)
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.27.17
#     Uninstalling botocore-1.27.17:
#       Successfully uninstalled botocore-1.27.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.25.17 requires botocore==1.27.17, but you have botocore 1.24.21 which is incompatible.
# Successfully installed botocore-1.24.21
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# !git clone https://github.com/fsspec/s3fs.git 
# %cd s3fs
# Out:
# Cloning into 's3fs'...
# remote: Enumerating objects: 3962, done.
# remote: Counting objects: 100% (806/806), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 3962 (delta 744), reused 661 (delta 657), pack-reused 3156
# Receiving objects: 100% (3962/3962), 951.56 KiB | 1.84 MiB/s, done.
# Resolving deltas: 100% (2699/2699), done.
# /content/clonedgit/subscriber/recipes/dataset-introduction/s3fs

# %%
import awscli
import setuptools
import os 
import pprint

# %%
temp_creds_url = all_pocloud_dataset('https://archive.podaac.earthdata.nasa.gov/s3credentials')

# %% [markdown]
# ---

# %% [markdown]
# ## Define function to determine environment

# %%
def environment():
    try:
        get_ipython()
        return "notebook"
    except:
        return "server"
environment()
# Out:
# 'notebook'

# %% [markdown]
# ---
#
#
#
# ---

# %%
# !pip install panel==0.12.6 hvplot==0.7.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting panel==0.12.6
#   Downloading panel-0.12.6-py2.py3-none-any.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 3.8 MB/s
# Collecting hvplot==0.7.3
#   Downloading hvplot-0.7.3-py2.py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 24.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (2.28.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (3.3.7)
# Requirement already satisfied: param>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (1.12.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (5.0.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (4.64.0)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (0.4.8)
# Collecting bokeh<2.5.0,>=2.4.0
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      |████████████████████████████████| 18.5 MB 1.5 MB/s
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from panel==0.12.6) (2.2.0)
# Requirement already satisfied: holoviews>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from hvplot==0.7.3) (1.14.9)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from hvplot==0.7.3) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from hvplot==0.7.3) (1.3.5)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.7/dist-packages (from hvplot==0.7.3) (3.0.0)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (2.11.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (3.13)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (7.1.2)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (5.1.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from bokeh<2.5.0,>=2.4.0->panel==0.12.6) (4.1.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh<2.5.0,>=2.4.0->panel==0.12.6) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh<2.5.0,>=2.4.0->panel==0.12.6) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->hvplot==0.7.3) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->hvplot==0.7.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->hvplot==0.7.3) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->panel==0.12.6) (0.5.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown->panel==0.12.6) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown->panel==0.12.6) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->panel==0.12.6) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->panel==0.12.6) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->panel==0.12.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->panel==0.12.6) (2.10)
# Installing collected packages: bokeh, panel, hvplot
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.3.3
#     Uninstalling bokeh-2.3.3:
#       Successfully uninstalled bokeh-2.3.3
#   Attempting uninstall: panel
#     Found existing installation: panel 0.12.1
#     Uninstalling panel-0.12.1:
#       Successfully uninstalled panel-0.12.1
# Successfully installed bokeh-2.4.3 hvplot-0.7.3 panel-0.12.6

# %%
import hvplot
import holoviews as hv

# %%
#https://nasa-openscapes.github.io/2021-Cloud-Hackathon/tutorials/05_Data_Access_Direct_S3.html

# %% [markdown]
# # GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
#
#
#
#
# ---
#
#
#
# > https://github.com/podaac/Data-Recipes/blob/main/dataset-introduction/AVHRR_OI-NCEI-L4-GLOB-v2.1.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ## Connecting to DataSets

# %%
# !pip install utils

# %%
# !pip install datetime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datetime in /usr/local/lib/python3.7/dist-packages (4.4)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.7/dist-packages (from datetime) (5.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from datetime) (2022.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zope.interface->datetime) (57.4.0)

# %%
# Connecting to datasets
import utils
import pprint
import xarray as xr
from datetime import datetime
import warnings

warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Code Block Repo Function 👽
# ---
#
#
#
# ---

# %%
#@title Repo Block Run Code
"""
Some ground level functions
"""

import requests
from pprint import pprint
CMR_OPS = 'https://cmr.earthdata.nasa.gov/search'
collection_url = 'https://cmr.earthdata.nasa.gov/search/collections'
var_url = "https://cmr.earthdata.nasa.gov/search/variables"

def find_dataset(provider='podaac',
                 keywords=['swot','level-2']):
    """
    Find a list of collections/datasets that match all the keywords from the keywords list.
    
    
    """
    import pandas as pd

    if 'podaac' in provider.lower().replace('.',''):
        provider='POCLOUD'
        
    response = requests.get(collection_url,params={'cloud_hosted': 'True',
                                        'has_granules': 'True',
                                        'provider': provider,
                                        'page_size':2000,},
                                headers={'Accept': 'application/json', } )
    
    collections = response.json()['feed']['entry']
    
    entries={}
    entries['short_name']=[]
    entries['long_name']=[]
    entries['concept_id']=[]
    entries['time_start']=[]
    entries['time_end']=[]
    
    
    for collection in collections:
        
        title="%s %s %s"%(collection["short_name"],collection["dataset_id"][:97],collection["id"])
        match=1
        for kw in keywords:
            match *= kw.lower() in title.lower()
            
        if match==1:
            entries['short_name'].append(collection["short_name"])
            entries['concept_id'].append(collection["id"])
            entries['long_name'].append(collection["dataset_id"])
            entries['time_start'].append(collection["time_start"])
            try:
                entries['time_end'].append(collection["time_end"])
            except:
                entries['time_end'].append(['NaT/Present'])
    
    return pd.DataFrame(entries)

def all_pocloud_dataset(provider='podaac'):
    """
    a list of all POCLOUD collections.
    """
    import pandas as pd

    if 'podaac' in provider.lower().replace('.',''):
        provider='POCLOUD'
        
    response = requests.get(collection_url,params={'cloud_hosted': 'True',
                                        'provider': provider,
                                        'page_size':2000,},
                                headers={'Accept': 'application/json', } )
    
    collections = response.json()['feed']['entry']
    
    entries={}
    entries['short_name']=[]
    entries['long_name']=[]
    entries['concept_id']=[]
    entries['time_start']=[]
    entries['time_end']=[]
    
    
    for collection in collections:
        
        title="%s %s %s"%(collection["short_name"],collection["dataset_id"][:97],collection["id"])
        match=1
        entries['short_name'].append(collection["short_name"])
        entries['concept_id'].append(collection["id"])
        entries['long_name'].append(collection["dataset_id"])
        entries['time_start'].append(collection["time_start"][:10])
        try:
            entries['time_end'].append(collection["time_end"][:10])
        except:
            entries['time_end'].append(['NaT/Present'])
    
    return pd.DataFrame(entries)

def direct_s3(provider='podaac'):
    import requests,s3fs
    s3_cred_endpoint = {
        'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials',
        'lpdaac':'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'}

    temp_creds_url = s3_cred_endpoint[provider]
    creds = requests.get(temp_creds_url).json()
    s3 = s3fs.S3FileSystem(anon=False,
                           key=creds['accessKeyId'],
                           secret=creds['secretAccessKey'], 
                           token=creds['sessionToken'])
    return s3

# %%
# Create Direct access to s3
def direct_s3(provider='podaac'):
    import requests,s3fs
    s3_cred_endpoint = {
        'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials',
        'lpdaac':'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'}

    temp_creds_url = s3_cred_endpoint[provider]
    creds = requests.get(temp_creds_url).json()
    s3 = s3fs.S3FileSystem(anon=False,
                           key=creds['accessKeyId'],
                           secret=creds['secretAccessKey'], 
                           token=creds['sessionToken'])
    return s3

# %% [markdown]
# ---
#
#
#
# ---

# %%
# Function Used

def direct_s3(provider='podaac'):
    import requests,s3fs
    s3_cred_endpoint = {
        'podaac':'https://archive.podaac.earthdata.nasa.gov/s3credentials',
        'lpdaac':'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'}

    temp_creds_url = s3_cred_endpoint[provider]
    creds = requests.get(temp_creds_url).json()
    s3 = s3fs.S3FileSystem(anon=False,
                           key=creds['accessKeyId'],
                           secret=creds['secretAccessKey'], 
                           token=creds['sessionToken'])
    return s3

# %% [markdown]
# ### Collecting Sets via S3 API from Main&Archived in Cloud ♎
#
#
# ---

# %%
# !pip install numpy
import numpy as np
import collections
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %%
#importing and Identifiying s3 Creds
#podaac_s3='podaac-ops-cumulus-protected'
#395 total collections in PODAAC CLOUD (POCLOUD) by 03/25/2022.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Finding DataSet Based On Keywords ⚡
#
#
# ---
#
# ---
#
#
#
#
#
# > Options:
#
# *   User Input
# *   Drop Down
# *   G-Form

# %%
# Keywords
find_dataset(keywords=['Sea Surface Temperature'])
sst_data = find_dataset(keywords=['Sea Surface Temperature'])
display(sst_data)
# Out:
#                                    short_name  \
# 0                        MUR-JPL-L4-GLOB-v4.1
# 1                     VIIRS_NPP-NAVO-L2P-v3.0
# 2           AVHRR_SST_METOP_B-OSISAF-L2P-v1.0
# 3               SEVIRI_IO_SST-OSISAF-L3C-v1.0
# 4                  SEVIRI_SST-OSISAF-L3C-v1.0
# 5                     MUR25-JPL-L4-GLOB-v04.2
# 6                     OSTIA-UKMO-L4-GLOB-v2.0
# 7                  CMC0.1deg-CMC-L4-GLOB-v3.0
# 8                    K10_SST-NAVO-L4-GLOB-v01
# 9                         AMSR2-REMSS-L2P-v8a
# 10                     AMSR2-REMSS-L2P_RT_v8a
# 11                   AVHRRMTA_G-NAVO-L2P-v1.0
# 12                   AVHRRMTB_G-NAVO-L2P-v1.0
# 13                 AVHRR_OI-NCEI-L4-GLOB-v2.1
# 14               GAMSSA_28km-ABOM-L4-GLOB-v01
# 15                        MSG03-OSPO-L2P-v1.0
# 16                           TMI-REMSS-L2P-v4
# 17                    VIIRS_NPP-NAVO-L2P-v1.0
# 18                        AMSR2-REMSS-L3U-v8a
# 19                     AMSR2-REMSS-L3U_RT-v8a
# 20                    AVHRR19_G-NAVO-L2P-v1.0
# 21                    AVHRR19_L-NAVO-L2P-v1.0
# 22                   AVHRRMTA_G-NAVO-L2P-v2.0
# 23                   AVHRRMTB_G-NAVO-L2P-v2.0
# 24                   AVHRRMTC_G-NAVO-L2P-v2.0
# 25      AVHRR_SST_METOP_B_GLB-OSISAF-L3C-v1.0
# 26      AVHRR_SST_METOP_B_NAR-OSISAF-L3C-v1.0
# 27                    DMI_OI-DMI-L4-GLOB-v1.0
# 28                         EWSG1-NAVO-L2P-v01
# 29                        GMI-REMSS-L3U-v8.2a
# 30                       GOES15-OSPO-L2P-v1.0
# 31                 GOES16-SST-OSISAF-L3C-v1.0
# 32        Geo_Polar_Blended-OSPO-L4-GLOB-v1.0
# 33  Geo_Polar_Blended_Night-OSPO-L4-GLOB-v1.0
# 34           IASI_SST_METOP_B-OSISAF-L2P-v1.0
# 35                MW_IR_OI-REMSS-L4-GLOB-v5.0
# 36                   MW_OI-REMSS-L4-GLOB-v5.0
# 37                RAMSSA_09km-ABOM-L4-AUS-v01
# 38                REYNOLDS_NCDC_L4_MONTHLY_V5
# 39              SEVIRI_SST_DR-OSISAF-L3C-v1.0
# 40                    VIIRS_NPP-NAVO-L2P-v2.0
# 41          VIIRS_SST_NPP_NAR-OSISAF-L3C-v1.0
# 42                  WindSat-REMSS-L3U-v7.0.1a
#
#                                                                                                                                                 long_name  \
# 0                                                                            GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 1   GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 2   GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 3   GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 4   GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
# 5                                                                    GHRSST Level 4 MUR 0.25deg Global Foundation Sea Surface Temperature Analysis (v4.2)
# 6                                                                 GHRSST Level 4 OSTIA Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 7                                                             GHRSST Level 4 CMC0.1deg Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 8                                   GHRSST Level 4 K10_SST Global 10 km Analyzed Sea Surface Temperature from Naval Oceanographic Office (NAVO) in GDS2.0
# 9             GHRSST Level 2P Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 10  GHRSST Level 2P Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 11  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-A satellite produced by NAVO
# 12  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-B satellite produced by NAVO
# 13                                                               GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# 14                                                      GHRSST Level 4 GAMSSA_28km Global Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 15  GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Sec...
# 16  GHRSST Level 2P Global Subskin Sea Surface Temperature from TRMM Microwave Imager (TMI) onboard Tropical Rainfall Measurement Mission (TRMM) satel...
# 17                                                             GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V1
# 18            GHRSST Level 3U Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 19  GHRSST Level 3U Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 20  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by NAVO
# 21  GHRSST Level 2P Regional 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by...
# 22                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-A satellite produced by NAVO
# 23                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-B satellite produced by NAVO
# 24                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-C satellite produced by NAVO
# 25  GHRSST L3C global sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-...
# 26                            GHRSST Level 3C North Atlantic Regional (NAR) subskin Sea Surface Temperature
# 22                   AVHRRMTA_G-NAVO-L2P-v2.0
# 23                   AVHRRMTB_G-NAVO-L2P-v2.0
# 24                   AVHRRMTC_G-NAVO-L2P-v2.0
# 25      AVHRR_SST_METOP_B_GLB-OSISAF-L3C-v1.0
# 26      AVHRR_SST_METOP_B_NAR-OSISAF-L3C-v1.0
# 27                    DMI_OI-DMI-L4-GLOB-v1.0
# 28                         EWSG1-NAVO-L2P-v01
# 29                        GMI-REMSS-L3U-v8.2a
# 30                       GOES15-OSPO-L2P-v1.0
# 31                 GOES16-SST-OSISAF-L3C-v1.0
# 32        Geo_Polar_Blended-OSPO-L4-GLOB-v1.0
# 33  Geo_Polar_Blended_Night-OSPO-L4-GLOB-v1.0
# 34           IASI_SST_METOP_B-OSISAF-L2P-v1.0
# 35                MW_IR_OI-REMSS-L4-GLOB-v5.0
# 36                   MW_OI-REMSS-L4-GLOB-v5.0
# 37                RAMSSA_09km-ABOM-L4-AUS-v01
# 38                REYNOLDS_NCDC_L4_MONTHLY_V5
# 39              SEVIRI_SST_DR-OSISAF-L3C-v1.0
# 40                    VIIRS_NPP-NAVO-L2P-v2.0
# 41          VIIRS_SST_NPP_NAR-OSISAF-L3C-v1.0
# 42                  WindSat-REMSS-L3U-v7.0.1a
#
#                                                                                                                                                 long_name  \
# 0                                                                            GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 1   GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 2   GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 3   GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 4   GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
# 5                                                                    GHRSST Level 4 MUR 0.25deg Global Foundation Sea Surface Temperature Analysis (v4.2)
# 6                                                                 GHRSST Level 4 OSTIA Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 7                                                             GHRSST Level 4 CMC0.1deg Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 8                                   GHRSST Level 4 K10_SST Global 10 km Analyzed Sea Surface Temperature from Naval Oceanographic Office (NAVO) in GDS2.0
# 9             GHRSST Level 2P Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 10  GHRSST Level 2P Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 11  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-A satellite produced by NAVO
# 12  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-B satellite produced by NAVO
# 13                                                               GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# 14                                                      GHRSST Level 4 GAMSSA_28km Global Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 15  GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Sec...
# 16  GHRSST Level 2P Global Subskin Sea Surface Temperature from TRMM Microwave Imager (TMI) onboard Tropical Rainfall Measurement Mission (TRMM) satel...
# 17                                                             GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V1
# 18            GHRSST Level 3U Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 19  GHRSST Level 3U Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 20  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by NAVO
# 21  GHRSST Level 2P Regional 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by...
# 22                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-A satellite produced by NAVO
# 23                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-B satellite produced by NAVO
# 24                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-C satellite produced by NAVO
# 25  GHRSST L3C global sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-...
# 26                            GHRSST Level 3C North Atlantic Regional (NAR) subskin Sea Surface Temperature from Metop/AVHRR (GDS V2) produced by OSI SAF
# 27                                                              GHRSST Level 4 DMI_OI Global Foundation Sea Surface Temperature Analysis  (GDS version 2)
# 28           GHRSST Level 2P Sea Surface Temperature version 1.0 from the Electro-Optical Infrared Weather System  Geostationary (EWSG1) produced by NAVO
# 29                                                                  GHRSST Level 3U Global Subskin Sea Surface Temperature from GMI onboard GPM satellite
# 30  GHRSST Level 2P Central Pacific Regional Skin Sea Surface Temperature from the Geostationary Operational Environmental Satellites (GOES) Imager on...
# 31                                           GHRSST L3C hourly America Region sub-skin Sea Surface Temperature v1.0 from ABI on GOES16 produced by OSISAF
# 32                                                                 GHRSST Level 4 OSPO Global Foundation Sea Surface Temperature Analysis (GDS version 2)
#
# 27  C2036881727-POCLOUD  2013-04-30T00:00:00.000Z             [NaT/Present]
# 28  C2184546470-POCLOUD  2021-12-06T00:00:00.000Z             [NaT/Present]
# 29  C2036877762-POCLOUD  2014-03-04T00:00:00.000Z             [NaT/Present]
# 30  C2036881909-POCLOUD  2013-08-01T13:22:00.000Z  2020-03-02T16:00:20.000Z
# 31  C2036877806-POCLOUD  2017-12-14T14:30:00.000Z             [NaT/Present]
# 32  C2036877754-POCLOUD  2014-06-02T00:00:00.000Z             [NaT/Present]
# 33  C2036877745-POCLOUD  2014-06-02T00:00:00.000Z             [NaT/Present]
# 34  C2036877829-POCLOUD  2016-01-07T03:35:55.000Z             [NaT/Present]
# 35  C2036878045-POCLOUD  2002-06-01T00:00:00.000Z             [NaT/Present]
# 36  C2036878052-POCLOUD  1997-12-31T16:00:00.000Z             [NaT/Present]
# 37  C2036878103-POCLOUD  2006-06-12T00:00:00.000Z             [NaT/Present]
# 38  C2036878116-POCLOUD  1854-01-01T00:00:00.000Z             [NaT/Present]
# 39  C2157151105-POCLOUD  2004-01-19T00:00:00.000Z  2012-12-31T23:59:59.000Z
# 40  C2036881016-POCLOUD  2016-02-25T17:30:00.000Z  2018-02-22T15:48:07.000Z
# 41  C2036878808-POCLOUD  2013-11-11T01:14:40.000Z             [NaT/Present]
# 42  C2036878925-POCLOUD  2002-06-01T19:15:00.000Z  2020-10-19T23:59:00.000Z

# %% [markdown]
# # ✌ Slicing and Indexing Variables:
#
#
# ---
# > Time :
# > Coordinates :
# > Temp

# %%
import datetime as dt
       # or
from datetime import date
d1 = dt.date(2020, 11, 19)
d1

# %%
 print(d1.year)
 print(d1.month)
 print(d1.day)
# Out:
# 2020
# 11
# 19

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Finding Earliest Date Example

# %%
earliest = Sea_Surface_Temperature['time_start'].min() # Earliest date
#newest = Sea_Surface_Temperature['time_end'].max() # Latest date

#print(newest)
print(earliest)
# Out:
# 1854-01-01T00:00:00.000Z

# %%
# Dropna

df= Sea_Surface_Temperature.dropna(how= 'any', axis =0).reset_index()

missing_vals = ["NA","", "[NaT/Present]",None, np.NAN]
missing = df.isin(missing_vals)
missing.head()

df.fillna(0).head()
# Out:
#    index                         short_name  \
# 0      0               MUR-JPL-L4-GLOB-v4.1
# 1      1            VIIRS_NPP-NAVO-L2P-v3.0
# 2      2  AVHRR_SST_METOP_B-OSISAF-L2P-v1.0
# 3      3      SEVIRI_IO_SST-OSISAF-L3C-v1.0
# 4      4         SEVIRI_SST-OSISAF-L3C-v1.0
#
#                                                                                                                                                long_name  \
# 0                                                                           GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 1  GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 2  GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 3  GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 4  GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
#
#             concept_id                time_start       time_end
# 0  C1996881146-POCLOUD  2002-05-31T21:00:00.000Z  [NaT/Present]
# 1  C1996881636-POCLOUD  2018-01-30T17:51:49.000Z  [NaT/Present]
# 2  C2036880717-POCLOUD  2016-01-19T08:07:03.000Z  [NaT/Present]
# 3  C2036877550-POCLOUD  2017-03-28T13:30:00.000Z  [NaT/Present]
# 4  C2036878243-POCLOUD  2004-06-01T00:00:00.000Z  [NaT/Present]

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# [Time Series Panda resource](https://pandas.pydata.org/docs/user_guide/timeseries.html)

# %%
short_name = 'NOAA Smith and Reynolds Extended Reconstructed Sea Surface Temperature (ERSST) Level 4 Monthly Version 5 Dataset in netCDF'

# %%
import pprint

# %%
from typing_extensions import get_origin
origin_value = get_origin(short_name)

# one Example
short_name="MUR-JPL-L4-GLOB-v4.1"
fns=sorted(s3.glob(podaac_s3+'/%s/*nc'%short_name))
print('There are %i files in this dataset.'%len(fns))
print('The first five files are:')
pprint.pprint(fns[:5])
print('The last five files are:')
pprint.pprint(fns[-5:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-b64f0602387d> in <module>()
#       4 # one Example
#       5 short_name="MUR-JPL-L4-GLOB-v4.1"
# ----> 6 fns=sorted(s3.glob(podaac_s3+'/%s/*nc'%short_name))
#       7 print('There are %i files in this dataset.'%len(fns))
#       8 print('The first five files are:')
#
# NameError: name 's3' is not defined

# %% [markdown]
# # Subscribing to datasets

# %%
# !pip install podaac_data_subscriber
#!pip install podaac
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: podaac_data_subscriber in /usr/local/lib/python3.7/dist-packages (1.10.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.0.1 in /usr/local/lib/python3.7/dist-packages (from podaac_data_subscriber) (8.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /usr/local/lib/python3.7/dist-packages (from podaac_data_subscriber) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.27.1->podaac_data_subscriber) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.27.1->podaac_data_subscriber) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.27.1->podaac_data_subscriber) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.27.1->podaac_data_subscriber) (2022.6.15)

# %%
import pytest
import os
from os.path import exists
from subscriber import podaac_data_downloader as pdd
import shutil
from pathlib import Path

# %%
def test_downloader_GRACE_with_SHA_512(tmpdir):
    # start with empty directory
    directory_str = str(tmpdir)
    assert len( os.listdir(directory_str) ) == 0

    # run the command once -> should download the file. Note the modified time for the file
    args = create_downloader_args(f"-c GRACEFO_L2_CSR_MONTHLY_0060 -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:01Z -d {str(tmpdir)} --limit 1 --verbose -e 00".split())
    pdd.run(args)
    assert len( os.listdir(directory_str) ) > 0
    filename = directory_str + "/" + os.listdir(directory_str)[0]
    modified_time_1 = os.path.getmtime(filename)
    print( modified_time_1 )

# %%
# Getting a url from this dataset
# !pip install urlextract
# A simple regex for URL matching like the following should fit your case.
from urllib.parse import urlparse
# !pip install wget
import wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting urlextract
#   Downloading urlextract-1.6.0-py3-none-any.whl (20 kB)
# Collecting uritools
#   Downloading uritools-4.0.0-py3-none-any.whl (10 kB)
# Collecting platformdirs
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from urlextract) (3.7.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from urlextract) (2.10)
# Installing collected packages: uritools, platformdirs, urlextract
# Successfully installed platformdirs-2.5.2 uritools-4.0.0 urlextract-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=c50c48d1151284aa907e657d15fb70f5bc249625254ea726cfa703d36f4935bb
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from sys import meta_path
from numpy.ma.core import get_data
from traitlets.traitlets import List
from posix import listdir
#from traitlets.traitlets import List
from urllib.request import url2pathname
#get_origin(Literal[38])

# %%
# Extracting URL  

# It works for some things, not all 

from urlextract import URLExtract
extractor = URLExtract()
urls = extractor.find_urls('MUR-JPL-L4-GLOB-v4.1')
print(urls)
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# ## Attemping to download straight to Google colab

# %% [markdown]
# ---

# %%
df
# Out:
#     index                                 short_name  \
# 0       0                       MUR-JPL-L4-GLOB-v4.1
# 1       1                    VIIRS_NPP-NAVO-L2P-v3.0
# 2       2          AVHRR_SST_METOP_B-OSISAF-L2P-v1.0
# 3       3              SEVIRI_IO_SST-OSISAF-L3C-v1.0
# 4       4                 SEVIRI_SST-OSISAF-L3C-v1.0
# 5       5                    MUR25-JPL-L4-GLOB-v04.2
# 6       6                    OSTIA-UKMO-L4-GLOB-v2.0
# 7       7                 CMC0.1deg-CMC-L4-GLOB-v3.0
# 8       8                   K10_SST-NAVO-L4-GLOB-v01
# 9       9                        AMSR2-REMSS-L2P-v8a
# 10     10                     AMSR2-REMSS-L2P_RT_v8a
# 11     11                   AVHRRMTA_G-NAVO-L2P-v1.0
# 12     12                   AVHRRMTB_G-NAVO-L2P-v1.0
# 13     13                 AVHRR_OI-NCEI-L4-GLOB-v2.1
# 14     14               GAMSSA_28km-ABOM-L4-GLOB-v01
# 15     15                        MSG03-OSPO-L2P-v1.0
# 16     16                           TMI-REMSS-L2P-v4
# 17     17                    VIIRS_NPP-NAVO-L2P-v1.0
# 18     18                        AMSR2-REMSS-L3U-v8a
# 19     19                     AMSR2-REMSS-L3U_RT-v8a
# 20     20                    AVHRR19_G-NAVO-L2P-v1.0
# 21     21                    AVHRR19_L-NAVO-L2P-v1.0
# 22     22                   AVHRRMTA_G-NAVO-L2P-v2.0
# 23     23                   AVHRRMTB_G-NAVO-L2P-v2.0
# 24     24                   AVHRRMTC_G-NAVO-L2P-v2.0
# 25     25      AVHRR_SST_METOP_B_GLB-OSISAF-L3C-v1.0
# 26     26      AVHRR_SST_METOP_B_NAR-OSISAF-L3C-v1.0
# 27     27                    DMI_OI-DMI-L4-GLOB-v1.0
# 28     28                         EWSG1-NAVO-L2P-v01
# 29     29                        GMI-REMSS-L3U-v8.2a
# 30     30                       GOES15-OSPO-L2P-v1.0
# 31     31                 GOES16-SST-OSISAF-L3C-v1.0
# 32     32        Geo_Polar_Blended-OSPO-L4-GLOB-v1.0
# 33     33  Geo_Polar_Blended_Night-OSPO-L4-GLOB-v1.0
# 34     34           IASI_SST_METOP_B-OSISAF-L2P-v1.0
# 35     35                MW_IR_OI-REMSS-L4-GLOB-v5.0
# 36     36                   MW_OI-REMSS-L4-GLOB-v5.0
# 37     37                RAMSSA_09km-ABOM-L4-AUS-v01
# 38     38                REYNOLDS_NCDC_L4_MONTHLY_V5
# 39     39              SEVIRI_SST_DR-OSISAF-L3C-v1.0
# 40     40                    VIIRS_NPP-NAVO-L2P-v2.0
# 41     41          VIIRS_SST_NPP_NAR-OSISAF-L3C-v1.0
# 42     42                  WindSat-REMSS-L3U-v7.0.1a
#
#                                                                                                                                                 long_name  \
# 0                                                                            GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)
# 1   GHRSST Level 2P 1 m Depth Global Sea Surface Temperature version 3.0 from the Visible Infrared Imaging Radiometer Suite (VIIRS) on the Suomi NPP s...
# 2   GHRSST Level 2P sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-B)...
# 3   GHRSST Level 3C Indian-Ocean (IO) sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG in GDS2 ...
# 4   GHRSST Level 3C Atlantic sub-skin Sea Surface Temperature from the Spinning Enhanced Visible and Infrared Imager (SEVIRI) on MSG at 0 degree longi...
# 5                                                                    GHRSST Level 4 MUR 0.25deg Global Foundation Sea Surface Temperature Analysis (v4.2)
# 6                                                                 GHRSST Level 4 OSTIA Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 7                                                             GHRSST Level 4 CMC0.1deg Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 8                                   GHRSST Level 4 K10_SST Global 10 km Analyzed Sea Surface Temperature from Naval Oceanographic Office (NAVO) in GDS2.0
# 9             GHRSST Level 2P Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 10  GHRSST Level 2P Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 11  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-A satellite produced by NAVO
# 12  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the MetOp-B satellite produced by NAVO
# 13                                                               GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# 14                                                      GHRSST Level 4 GAMSSA_28km Global Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 15  GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Sec...
# 16  GHRSST Level 2P Global Subskin Sea Surface Temperature from TRMM Microwave Imager (TMI) onboard Tropical Rainfall Measurement Mission (TRMM) satel...
# 17                                                             GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V1
# 18            GHRSST Level 3U Global Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W satellite
# 19  GHRSST Level 3U Global Near-Real-Time Subskin Sea Surface Temperature version 8a from the Advanced Microwave Scanning Radiometer 2 on the GCOM-W s...
# 20  GHRSST Level 2P Global 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by NAVO
# 21  GHRSST Level 2P Regional 1m Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on the NOAA-19 satellite produced by...
# 22                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-A satellite produced by NAVO
# 23                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-B satellite produced by NAVO
# 24                                           GHRSST Level 2P Global Sea Surface Temperature v2.0 from the AVHRR on the MetOp-C satellite produced by NAVO
# 25  GHRSST L3C global sub-skin Sea Surface Temperature from the Advanced Very High Resolution Radiometer (AVHRR) on Metop satellites (currently Metop-...
# 26                            GHRSST Level 3C North Atlantic Regional (NAR) subskin Sea Surface Temperature from Metop/AVHRR (GDS V2) produced by OSI SAF
# 27                                                              GHRSST Level 4 DMI_OI Global Foundation Sea Surface Temperature Analysis  (GDS version 2)
# 28           GHRSST Level 2P Sea Surface Temperature version 1.0 from the Electro-Optical Infrared Weather System  Geostationary (EWSG1) produced by NAVO
# 29                                                                  GHRSST Level 3U Global Subskin Sea Surface Temperature from GMI onboard GPM satellite
# 30  GHRSST Level 2P Central Pacific Regional Skin Sea Surface Temperature from the Geostationary Operational Environmental Satellites (GOES) Imager on...
# 31                                           GHRSST L3C hourly America Region sub-skin Sea Surface Temperature v1.0 from ABI on GOES16 produced by OSISAF
# 32                                                                 GHRSST Level 4 OSPO Global Foundation Sea Surface Temperature Analysis (GDS version 2)
# 33                                                       GHRSST Level 4 OSPO Global Nighttime Foundation Sea Surface Temperature Analysis (GDS version 2)
# 34  GHRSST Level 2P Global skin Sea Surface Temperature from the Infrared Atmospheric Sounding Interferometer (IASI) on the Metop-B satellite (GDS V2)...
# 35                                                      GHRSST Level 4 MW_IR_OI Global Foundation Sea Surface Temperature analysis version 5.0 from REMSS
# 36                                                         GHRSST Level 4 MW_OI Global Foundation Sea Surface Temperature analysis version 5.0 from REMSS
# 37                                          GHRSST Level 4 RAMSSA_9km Australian Regional Foundation Sea Surface Temperature Analysis v1.0 dataset (GDS2)
# 38                             NOAA Smith and Reynolds Extended Reconstructed Sea Surface Temperature (ERSST) Level 4 Monthly Version 5 Dataset in netCDF
# 39                         GHRSST L3C hourly Atlantic reprocessed sub-skin sea surface temperature data record v1.0 from SEVIRI on MSG produced by OSISAF
# 40                                                             GHRSST Level 2P 1 m Depth Global Sea Surface Temperature from VIIRS on Suomi NPP (GDS2) V2
POCLOUD  2014-06-02T00:00:00.000Z             [NaT/Present]
# 33  C2036877745-POCLOUD  2014-06-02T00:00:00.000Z             [NaT/Present]
# 34  C2036877829-POCLOUD  2016-01-07T03:35:55.000Z             [NaT/Present]
# 35  C2036878045-POCLOUD  2002-06-01T00:00:00.000Z             [NaT/Present]
# 36  C2036878052-POCLOUD  1997-12-31T16:00:00.000Z             [NaT/Present]
# 37  C2036878103-POCLOUD  2006-06-12T00:00:00.000Z             [NaT/Present]
# 38  C2036878116-POCLOUD  1854-01-01T00:00:00.000Z             [NaT/Present]
# 39  C2157151105-POCLOUD  2004-01-19T00:00:00.000Z  2012-12-31T23:59:59.000Z
# 40  C2036881016-POCLOUD  2016-02-25T17:30:00.000Z  2018-02-22T15:48:07.000Z
# 41  C2036878808-POCLOUD  2013-11-11T01:14:40.000Z             [NaT/Present]
# 42  C2036878925-POCLOUD  2002-06-01T19:15:00.000Z  2020-10-19T23:59:00.000Z

# %%
#Direct Access using S3

# %%
#-s 20200101 -t curl -f 20200710 -x OSCAR_L4_OC_third-deg

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # DataSubscriber UseCase
#
#
# ---
#
#
#
# > podaac-data-downloader
# https://github.com/podaac/data-subscriber/blob/main/Downloader.md
# https://github.com/podaac/data-subscriber/blob/main/BUILD.md

# %%
#podaac-data-downloader -c SENTINEL-1A_SLC -d myData -f
#pdd -c SENTINEL-1A_SLC -d myData -f

# !pip install poetry

# %%
import poetry
import pytest

# %%
#@title Test Case
import pytest
import os
from os.path import exists
from subscriber import podaac_data_downloader as pdd
import shutil
from pathlib import Path

# REGRESSION TEST CURRENTLY REQUIRES A .NETRC file for CMR/Data Download

def create_downloader_args(args):
    parser = pdd.create_parser()
    args2 = parser.parse_args(args)
    return args2


#Test the downlaoder on MUR25 data for start/stop/, yyyy/mmm/dd dir structure,
# and offset. Running it a second time to ensure it downlaods the files again-
# the downloader doesn't care about updates.
@pytest.mark.regression
def test_downloader_limit_MUR():
    shutil.rmtree('./MUR25-JPL-L4-GLOB-v04.2', ignore_errors=True)
    args2 = create_downloader_args('-c MUR25-JPL-L4-GLOB-v04.2 -d ./MUR25-JPL-L4-GLOB-v04.2  -sd 2020-01-01T00:00:00Z -ed 2020-01-30T00:00:00Z --limit 1'.split())
    pdd.run(args2)
    # count number of files downloaded...
    assert len([name for name in os.listdir('./MUR25-JPL-L4-GLOB-v04.2') if os.path.isfile('./MUR25-JPL-L4-GLOB-v04.2/' + name)])==1
    shutil.rmtree('./MUR25-JPL-L4-GLOB-v04.2')

#Test the downlaoder on MUR25 data for start/stop/, yyyy/mmm/dd dir structure,
# and offset. Running it a second time to ensure it downlaods the files again-
# the downloader doesn't care about updates.
@pytest.mark.regression
def test_downloader_MUR():
    shutil.rmtree('./MUR25-JPL-L4-GLOB-v04.2', ignore_errors=True)
    args2 = create_downloader_args('-c MUR25-JPL-L4-GLOB-v04.2 -d ./MUR25-JPL-L4-GLOB-v04.2  -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:00Z -dymd --offset 4'.split())
    pdd.run(args2)
    assert exists('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    assert exists('./MUR25-JPL-L4-GLOB-v04.2/2020/01/02/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    t1 = os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    t2 = os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/02/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')

    # this part of the test should not re-download the files unless the --force
    # option is used.
    pdd.run(args2)
    assert t1 == os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    assert t2 == os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/02/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')

    # Update a file to change the checksum, then re-download
    os.remove('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    Path('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc').touch()
    pdd.run(args2)
    assert t1 != os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    assert t2 == os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/02/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')

    t1 = os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')

    # Set the args to --force to re-download those data
    args2 = create_downloader_args('-c MUR25-JPL-L4-GLOB-v04.2 -d ./MUR25-JPL-L4-GLOB-v04.2  -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:00Z -dymd --offset 4 -f'.split())
    pdd.run(args2)
    assert t1 != os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/01/20200101090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')
    assert t2 != os.path.getmtime('./MUR25-JPL-L4-GLOB-v04.2/2020/01/02/20200102090000-JPL-L4_GHRSST-SSTfnd-MUR25-GLOB-v02.0-fv04.2.nc')

    shutil.rmtree('./MUR25-JPL-L4-GLOB-v04.2')


@pytest.mark.regression
def test_downloader_GRACE_with_SHA_512(tmpdir):
    # start with empty directory
    directory_str = str(tmpdir)
    assert len( os.listdir(directory_str) ) == 0

    # run the command once -> should download the file. Note the modified time for the file
    args = create_downloader_args(f"-c GRACEFO_L2_CSR_MONTHLY_0060 -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:01Z -d {str(tmpdir)} --limit 1 --verbose -e 00".split())
    pdd.run(args)
    assert len( os.listdir(directory_str) ) > 0
    filename = directory_str + "/" + os.listdir(directory_str)[0]
    modified_time_1 = os.path.getmtime(filename)
    print( modified_time_1 )

    # run the command again -> should not redownload the file. The modified time for the file should not change
    pdd.run(args)
    modified_time_2 = os.path.getmtime(filename)
    print( modified_time_2 )
    assert modified_time_1 == modified_time_2

# %%
# run the command once -> should download the file. Note the modified time for the file
args = create_downloader_args(f"-c GRACEFO_L2_CSR_MONTHLY_0060 -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:01Z -d {str(tmpdir)} --limit 1 --verbose -e 00".split())
pdd.run(args)
assert len( os.listdir(directory_str) ) > 0
filename = directory_str + "/" + os.listdir(directory_str)[0]
modified_time_1 = os.path.getmtime(filename)
print( modified_time_1 )

    # run the command again -> should not redownload the file. The modified time for the file should not change
pdd.run(args)
modified_time_2 = os.path.getmtime(filename)
print(modified_time_2)
assert modified_time_1 == modified_time_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4fcb7c6c734d> in <module>()
#       1 # run the command once -> should download the file. Note the modified time for the file
# ----> 2 args = create_downloader_args(f"-c GRACEFO_L2_CSR_MONTHLY_0060 -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:01Z -d {str(tmpdir)} --limit 1 --verbose -e 00".split())
#       3 pdd.run(args)
#       4 assert len( os.listdir(directory_str) ) > 0
#       5 filename = directory_str + "/" + os.listdir(directory_str)[0]
#
# NameError: name 'tmpdir' is not defined

# %%
#!/usr/bin/env python3
import argparse
import logging
import os
import sys
from datetime import datetime, timedelta
from os import makedirs
from os.path import isdir, basename, join, exists
from urllib.error import HTTPError
from urllib.request import urlretrieve

from subscriber import podaac_access as pa

__version__ = pa.__version__

page_size = 2000
edl = pa.edl
cmr = pa.cmr
token_url = pa.token_url

# The lines below are to get the IP address. You can make this static and
# assign a fixed value to the IPAddr variable

def parse_cycles(cycle_input):
    # if cycle_input is None:
    #     return None
    # if isinstance(cycle_input, list):
    #     return cycle_input
    # return [int(cycle_input)]
    return


def validate(args):
    if args.search_cycles is None and args.startDate is None and args.endDate is None:
        raise ValueError(
            "Error parsing command line arguments: one of [--start-date and --end-date] or [--cycles] are required")  # noqa E501
    if args.search_cycles is not None and args.startDate is not None:
        raise ValueError(
            "Error parsing command line arguments: only one of -sd/--start-date and --cycles are allowed")  # noqa E501
    if args.search_cycles is not None and args.endDate is not None:
        raise ValueError(
            "Error parsing command line arguments: only one of -ed/--end-date and --cycles are allowed")  # noqa E50
    if None in [args.endDate, args.startDate] and args.search_cycles is None:
        raise ValueError(
            "Error parsing command line arguments: Both --start-date and --end-date must be specified")  # noqa E50


def create_parser():
    # Initialize parser
    parser = argparse.ArgumentParser(prog='PO.DAAC bulk-data downloader')

    # Adding Required arguments
    parser.add_argument("-c", "--collection-shortname", dest="collection", required=True,
                        help="The collection shortname for which you want to retrieve data.")  # noqa E501
    parser.add_argument("-d", "--data-dir", dest="outputDirectory", required=True,
                        help="The directory where data products will be downloaded.")  # noqa E501

    # Required through validation
    parser.add_argument("--cycle", required=False, dest="search_cycles",
                        help="Cycle number for determining downloads. can be repeated for multiple cycles",
                        action='append', type=int)
    parser.add_argument("-sd", "--start-date", required=False, dest="startDate",
                        help="The ISO date time before which data should be retrieved. For Example, --start-date 2021-01-14T00:00:00Z")  # noqa E501
    parser.add_argument("-ed", "--end-date", required=False, dest="endDate",
                        help="The ISO date time after which data should be retrieved. For Example, --end-date 2021-01-14T00:00:00Z")  # noqa E501

    # Adding optional arguments
    parser.add_argument("-f", "--force", dest="force", action="store_true", help = "Flag to force downloading files that are listed in CMR query, even if the file exists and checksum matches")  # noqa E501

    # spatiotemporal arguments
    parser.add_argument("-b", "--bounds", dest="bbox",
                        help="The bounding rectangle to filter result in. Format is W Longitude,S Latitude,E Longitude,N Latitude without spaces. Due to an issue with parsing arguments, to use this command, please use the -b=\"-180,-90,180,90\" syntax when calling from the command line. Default: \"-180,-90,180,90\".",
                        default=None)  # noqa E501

    # Arguments for how data are stored locally - much processing is based on
    # the underlying directory structure (e.g. year/Day-of-year)
    parser.add_argument("-dc", dest="cycle", action="store_true",
                        help="Flag to use cycle number for directory where data products will be downloaded.")  # noqa E501
    parser.add_argument("-dydoy", dest="dydoy", action="store_true",
                        help="Flag to use start time (Year/DOY) of downloaded data for directory where data products will be downloaded.")  # noqa E501
    parser.add_argument("-dymd", dest="dymd", action="store_true",
                        help="Flag to use start time (Year/Month/Day) of downloaded data for directory where data products will be downloaded.")  # noqa E501
    parser.add_argument("-dy", dest="dy", action="store_true",
                        help="Flag to use start time (Year) of downloaded data for directory where data products will be downloaded.")  # noqa E501
    parser.add_argument("--offset", dest="offset",
                        help="Flag used to shift timestamp. Units are in hours, e.g. 10 or -10.")  # noqa E501

    parser.add_argument("-e", "--extensions", dest="extensions",
                        help="The extensions of products to download. Default is [.nc, .h5, .zip, .tar.gz]",
                        default=None, action='append')  # noqa E501
    parser.add_argument("--process", dest="process_cmd",
                        help="Processing command to run on each downloaded file (e.g., compression). Can be specified multiple times.",
                        action='append')

    parser.add_argument("--version", action="version", version='%(prog)s ' + __version__,
                        help="Display script version information and exit.")  # noqa E501
    parser.add_argument("--verbose", dest="verbose", action="store_true", help="Verbose mode.")  # noqa E501
    parser.add_argument("-p", "--provider", dest="provider", default='POCLOUD',
                        help="Specify a provider for collection search. Default is POCLOUD.")  # noqa E501

    parser.add_argument("--limit", dest="limit", default=None, type=int,
                        help="Integer limit for number of granules to download. Useful in testing. Defaults to no limit.")  # noqa E501

    return parser


def run(args=None):
    if args is None:
        parser = create_parser()
        args = parser.parse_args()

    try:
        pa.validate(args)

        # download specific validations
        # cannot specify all thre options (start, end, cycle)
        # must specify start/end togeher
        # if cycle, then no sd/ed can be given, and vice versa
        validate(args)

    except ValueError as v:
        logging.error(str(v))
        exit(1)

    pa.setup_earthdata_login_auth(edl)
    token = pa.get_token(token_url, 'podaac-subscriber', edl)

    provider = args.provider
    start_date_time = args.startDate
    end_date_time = args.endDate
    search_cycles = args.search_cycles
    short_name = args.collection
    extensions = args.extensions
    process_cmd = args.process_cmd
    data_path = args.outputDirectory

    download_limit = None
    if args.limit is not None and args.limit > 0:
        download_limit = args.limit

    if args.offset:
        ts_shift = timedelta(hours=int(args.offset))

    # Error catching for output directory specifications
    # Must specify -d output path or one time-based output directory flag

    if sum([args.cycle, args.dydoy, args.dymd, args.dy]) > 1:
        parser.error('Too many output directory flags specified, '
                     'Please specify exactly one flag '
                     'from -dc, -dy, -dydoy, or -dymd')

    # This cell will replace the timestamp above with the one read from the `.update` file in the data directory, if it exists.

    if not isdir(data_path):
        logging.info("NOTE: Making new data directory at " + data_path + "(This is the first run.)")
        makedirs(data_path, exist_ok=True)

    if search_cycles is not None:
        cmr_cycles = search_cycles
        params = [
            ('page_size', page_size),
            ('sort_key', "-start_date"),
            ('provider', provider),
            ('ShortName', short_name),
            ('token', token),
        ]
        for v in cmr_cycles:
            params.append(("cycle[]", v))
        if args.verbose:
            logging.info("cycles: " + str(cmr_cycles))

    else:
        temporal_range = pa.get_temporal_range(start_date_time, end_date_time,
                                               datetime.utcnow().strftime("%Y-%m-%dT%H:%M:%SZ"))  # noqa E501
        params = [
            ('page_size', page_size),
            ('sort_key', "-start_date"),
            ('provider', provider),
            ('ShortName', short_name),
            ('temporal', temporal_range),
        ]
        if args.verbose:
            logging.info("Temporal Range: " + temporal_range)

    if args.verbose:
        logging.info("Provider: " + provider)
    if args.bbox is not None:
        params.append(('bounding_box', args.bbox))

    # If 401 is raised, refresh token and try one more time
    try:
        results = pa.get_search_results(params, args.verbose)
    except HTTPError as e:
        if e.code == 401:
            token = pa.refresh_token(token, 'podaac-subscriber')
            params['token'] = token
            results = pa.get_search_results(params, args.verbose)
        else:
            raise e

    if args.verbose:
        logging.info(str(results['hits']) + " granules found for " + short_name)  # noqa E501

    if any([args.dy, args.dydoy, args.dymd]):
        file_start_times = pa.parse_start_times(results)
    elif args.cycle:
        cycles = pa.parse_cycles(results)

    downloads_all = []
    downloads_data = [[u['URL'] for u in r['umm']['RelatedUrls'] if
                       u['Type'] == "GET DATA" and ('Subtype' not in u or u['Subtype'] != "OPENDAP DATA")] for r in
                      results['items']]
    downloads_metadata = [[u['URL'] for u in r['umm']['RelatedUrls'] if u['Type'] == "EXTENDED METADATA"] for r in
                          results['items']]
    checksums = pa.extract_checksums(results)

    for f in downloads_data:
        downloads_all.append(f)
    for f in downloads_metadata:
        downloads_all.append(f)

    downloads = [item for sublist in downloads_all for item in sublist]

    if len(downloads) >= page_size:
        logging.warning("Only the most recent " + str(
            page_size) + " granules will be downloaded; try adjusting your search criteria (suggestion: reduce time period or spatial region of search) to ensure you retrieve all granules.")

    # filter list based on extension
    if not extensions:
        extensions = pa.extensions
    filtered_downloads = []
    for f in downloads:
        for extension in extensions:
            if f.lower().endswith(extension):
                filtered_downloads.append(f)

    downloads = filtered_downloads

    # https://github.com/podaac/data-subscriber/issues/33
    # Make this a non-verbose message
    # if args.verbose:
    logging.info("Found " + str(len(downloads)) + " total files to download")
    if download_limit:
        logging.info("Limiting downloads to " + str(args.limit) + " total files")
    if args.verbose:
        logging.info("Downloading files with extensions: " + str(extensions))

    # NEED TO REFACTOR THIS, A LOT OF STUFF in here
    # Finish by downloading the files to the data directory in a loop.
    # Overwrite `.update` with a new timestamp on success.
    success_cnt = failure_cnt = skip_cnt = 0
    for f in downloads:
        try:
            # -d flag, args.outputDirectory
            output_path = join(data_path, basename(f))
            # -dy, args.dy, -dydoy, args.dydoy and -dymd, args.dymd
            if any([args.dy, args.dydoy, args.dymd]):
                output_path = pa.prepare_time_output(
                    file_start_times, data_path, f, args, ts_shift)
            # -dc flag
            if args.cycle:
                output_path = pa.prepare_cycles_output(
                    cycles, data_path, f)

            # decide if we should actually download this file (e.g. we may already have the latest version)
            if(exists(output_path) and not args.force and pa.checksum_does_match(output_path, checksums)):
                logging.info(str(datetime.now()) + " SKIPPED: " + f)
                skip_cnt += 1
                continue

            urlretrieve(f, output_path)
            pa.process_file(process_cmd, output_path, args)
            logging.info(str(datetime.now()) + " SUCCESS: " + f)
            success_cnt = success_cnt + 1

            #if limit is set and we're at or over it, stop downloading
            if download_limit and success_cnt >= download_limit:
                break

        except Exception:
            logging.warning(str(datetime.now()) + " FAILURE: " + f, exc_info=True)
            failure_cnt = failure_cnt + 1

    logging.info("Downloaded Files: " + str(success_cnt))
    logging.info("Failed Files:     " + str(failure_cnt))
    logging.info("Skipped Files:    " + str(skip_cnt))
    pa.delete_token(token_url, token)
    logging.info("END\n\n")




def main():
    log_level = os.environ.get('PODAAC_LOGLEVEL', 'INFO').upper()
    # %tb
    logging.basicConfig(stream=sys.stdout,
                        format='[%(asctime)s] {%(filename)s:%(lineno)d} %(levelname)s - %(message)s',
                        level=log_level)
    logging.debug("Log level set to " + log_level)

    try:
        run()
    except Exception as e:
        logging.exception("Uncaught exception occurred during execution.")
        exit(hash(e))


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4fcb7c6c734d> in <module>()
#       1 # run the command once -> should download the file. Note the modified time for the file
# ----> 2 args = create_downloader_args(f"-c GRACEFO_L2_CSR_MONTHLY_0060 -sd 2020-01-01T00:00:00Z -ed 2020-01-02T00:00:01Z -d {str(tmpdir)} --limit 1 --verbose -e 00".split())
#       3 pdd.run(args)
#       4 assert len( os.listdir(directory_str) ) > 0
#       5 filename = directory_str + "/" + os.listdir(directory_str)[0]
#
# NameError: name 'tmpdir' is not defined
# usage: PO.DAAC bulk-data downloader [-h] -c COLLECTION -d OUTPUTDIRECTORY
#                                     [--cycle SEARCH_CYCLES] [-sd STARTDATE]
#                                     [-ed ENDDATE] [-f] [-b BBOX] [-dc]
#                                     [-dydoy] [-dymd] [-dy] [--offset OFFSET]
#                                     [-e EXTENSIONS] [--process PROCESS_CMD]
#                                     [--version] [--verbose] [-p PROVIDER]
#                                     [--limit LIMIT]
# PO.DAAC bulk-data downloader: error: the following arguments are required: -c/--collection-shortname, -d/--data-dir
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
create_downloader_args()

# %% [markdown]
# # Direct Access to S3 Token

# %%
# !pip -q install boto3

# %%
import pytest
import os
from os.path import exists
from subscriber import podaac_data_downloader as pdd
import shutil
from pathlib import Path

# %% [markdown]
# ---

# %% [markdown]
# # Authenticate
#
#
# ---
#
#
#
# > Visit https://archive.podaac.earthdata.nasa.gov/s3credentials to get your access_key, secrect_access_key, and token. Paste the response into the s3_credential area below.

# %%
#https://archive.podaac.earthdata.nasa.gov/s3credentials
import json
import xarray as xr
# %matplotlib inline

# Paste the result of your accessing and login to the s3Credential endpoint above into the 's3_credential' variable here:
s3_credential = '{"accessKeyId": "", "secretAccessKey": "", "sessionToken": "", "expiration": "2022-06-26 22:50:58+00:00"}'
creds = json.loads(s3_credential)
# Out:
# [2022-07-30 09:54:29,774] {utils.py:160} INFO - NumExpr defaulting to 4 threads.

# %%
# Client Lib

s3_client = boto3.client(
    's3',
    aws_access_key_id=creds["accessKeyId"],
    aws_secret_access_key=creds["secretAccessKey"],
    aws_session_token=creds["sessionToken"]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2a9dc8755a21> in <module>()
#       1 # Client Lib
#       2
# ----> 3 s3_client = boto3.client(
#       4     's3',
#       5     aws_access_key_id=creds["accessKeyId"],
#
# NameError: name 'boto3' is not defined

# %%
#s3_client.download_file()
print(df[:])

import DateTime

pdd(df)

#pdd('GHRSST Level 4 MUR Global Foundation Sea Surface Temperature Analysis (v4.1)',)
#df3 = files.download('NOAA Smith and Reynolds Extended Reconstructed...')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3c200fec4a08> in <module>()
#       1
#       2 #s3_client.download_file()
# ----> 3 print(df[:])
#       4
#       5 import DateTime
#
# NameError: name 'df' is not defined

# %%
df.from_records(df[:])

# %%
#s3_client.download_file("podaac-ops-cumulus-protected", "ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4/ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc","ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc")
s3_client.list_objects()

# %% [markdown]
# ---

# %% [markdown]
# # Creating Interactive Display Inline

# %%
# !pip install asyncio
# !pip install aiobotocore
# !pip install botocore
# !pip install s3fs
# !pip install --upgrade s3fs

# %%
# %matplotlib inline

# %%
# !pip install panel==0.12.6 hvplot==0.7.3

# %%
import panel as pn

pn.extension('tabulator', sizing_mode="stretch_width")

# %%
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')
